# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator
# Out:
# /content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator

# %%
# !apt-get -y install ffmpeg libreoffice poppler-utils poppler-data locales \
                   fonts-noto-cjk fonts-noto-cjk-extra fonts-nanum fonts-unfonts-core
# !apt-get install -y libreoffice-impress libreoffice-common poppler-utils fonts-noto-cjk fonts-nanum
# !sed -i 's/^# *ko_KR.UTF-8 UTF-8/ko_KR.UTF-8 UTF-8/' /etc/locale.gen
# !locale-gen ko_KR.UTF-8
# !update-locale LANG=ko_KR.UTF-8
# !fc-cache -fv
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# locales is already the newest version (2.35-0ubuntu3.11).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   apparmor at-spi2-core default-jre default-jre-headless dictionaries-common
#   firebird3.0-common firebird3.0-common-doc firebird3.0-server-core
#   firebird3.0-utils fonts-crosextra-caladea fonts-crosextra-carlito
#   fonts-dejavu fonts-dejavu-core fonts-dejavu-extra fonts-liberation2
#   fonts-linuxlibertine fonts-noto-core fonts-noto-extra fonts-noto-mono
#   fonts-noto-ui-core fonts-opensymbol fonts-sil-gentium
#   fonts-sil-gentium-basic gsettings-desktop-schemas gstreamer1.0-gl
#   gstreamer1.0-gtk3 gstreamer1.0-plugins-base hunspell-en-us libabsl20210324
#   libabw-0.1-1 libatk-bridge2.0-0 libatk-wrapper-java libatk-wrapper-java-jni
#   libatk1.0-0 libatk1.0-data libatspi2.0-0 libboost-filesystem1.74.0
#   libboost-iostreams1.74.0 libboost-locale1.74.0 libboost-thread1.74.0
#   libbsh-java libcdparanoia0 libcdr-0.1-1 libclucene-contribs1v5
#   libclucene-core1v5 libcolamd2 libe-book-0.1-1 libel-api-java libeot0
#   libepubgen-0.1-1 libetonyek-0.1-1 libexttextcat-2.0-0 libexttextcat-data
#   libfbclient2 libfreehand-0.1-1 libgpgme11 libgpgmepp6 libgstreamer-gl1.0-0
#   libgstreamer-plugins-base1.0-0 libgtk-3-0 libgtk-3-bin libgtk-3-common
#   libgudev-1.0-0 libharfbuzz-icu0 libhsqldb1.8.0-java libhunspell-1.7-0
#   libhyphen0 libib-util libjsp-api-java liblangtag-common liblangtag1
#   liblibreoffice-java libmhash2 libmspub-0.1-1 libmwaw-0.3-3 libmythes-1.2-0
#   libodfgen-0.1-1 liborc-0.4-0 liborcus-0.17-0 liborcus-parser-0.17-0
#   libpagemaker-0.0-0 libraptor2-0 librasqal3 librdf0 libreoffice-base
#   libreoffice-base-core libreoffice-base-drivers libreoffice-calc
#   libreoffice-common libreoffice-core libreoffice-draw libreoffice-gnome
#   libreoffice-gtk3 libreoffice-impress libreoffice-java-common
#   libreoffice-math libreoffice-nlpsolver libreoffice-report-builder
#   libreoffice-report-builder-bin libreoffice-script-provider-bsh
#   libreoffice-script-provider-js libreoffice-script-provider-python
#   libreoffice-sdbc-firebird libreoffice-sdbc-hsqldb libreoffice-sdbc-mysql
#   libreoffice-sdbc-postgresql libreoffice-style-colibre
#   libreoffice-style-elementary libreoffice-style-yaru
#   libreoffice-wiki-publisher libreoffice-writer librevenge-0.0-0
#   librsvg2-common libservlet-api-java libservlet3.1-java libsuitesparseconfig5
#   libtext-iconv-perl libtommath1 libuno-cppu3 libuno-cppuhelpergcc3-3
#   libuno-purpenvhelpergcc3-3 libuno-sal3 libuno-salhelpergcc3-3
#   libunoloader-java libvisio-0.1-1 libvisual-0.4-0 libwebsocket-api-java
#   libwpd-0.10-10 libwpg-0.3-3 libwps-0.4-4 libxcomposite1 libxmlsec1
#   libxmlsec1-nss libxtst6 libxxf86dga1 libyajl2 lp-solve openjdk-11-jre
#   openjdk-11-jre-headless python3-uno session-migration uno-libs-private ure
#   ure-java x11-utils
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils ispell | aspell | hunspell wordlist
#   firebird3.0-server firebird3.0-doc gvfs hunspell openoffice.org-hunspell
#   | openoffice.org-core libvisual-0.4-plugins java-virtual-machine
#   libhsqldb1.8.0-java-gcj raptor2-utils rasqal-utils librdf-storage-postgresql
#   librdf-storage-mysql librdf-storage-sqlite librdf-storage-virtuoso
#   redland-utils cups-bsd firefox | firefox-esr | thunderbird ghostscript gpa
#   hyphen-hyphenation-patterns imagemagick | graphicsmagick-imagemagick-compat
#   libreoffice-grammarcheck libreoffice-help libreoffice-l10n
#   libreoffice-librelogo myspell-dictionary mythes-thesaurus
#   openclipart-libreoffice pstoedit unixodbc gstreamer1.0-plugins-good
#   gstreamer1.0-plugins-ugly gstreamer1.0-plugins-bad gstreamer1.0-libav
#   libsane1 libofficebean-java libjtds-java libsqliteodbc | tdsodbc
#   | odbc-mdbtools libreoffice-evolution seahorse libreofficekit-data bluez
#   default-mysql-server | virtual-mysql-server postgresql mediawiki libnss-mdns
#   fonts-ipafont-gothic fonts-ipafont-mincho fonts-wqy-microhei
#   | fonts-wqy-zenhei fonts-indic fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming mesa-utils
# The following NEW packages will be installed:
#   apparmor at-spi2-core default-jre default-jre-headless dictionaries-common
#   firebird3.0-common firebird3.0-common-doc firebird3.0-server-core
#   firebird3.0-utils fonts-crosextra-caladea fonts-crosextra-carlito
#   fonts-dejavu fonts-dejavu-core fonts-dejavu-extra fonts-liberation2
#   fonts-linuxlibertine fonts-nanum fonts-noto-cjk fonts-noto-cjk-extra
#   fonts-noto-core fonts-noto-extra fonts-noto-mono fonts-noto-ui-core
#   fonts-opensymbol fonts-sil-gentium fonts-sil-gentium-basic
#   fonts-unfonts-core gsettings-desktop-schemas gstreamer1.0-gl
#   gstreamer1.0-gtk3 gstreamer1.0-plugins-base hunspell-en-us libabsl20210324
#   libabw-0.1-1 libatk-bridge2.0-0 libatk-wrapper-java libatk-wrapper-java-jni
#   libatk1.0-0 libatk1.0-data libatspi2.0-0 libboost-filesystem1.74.0
#   libboost-iostreams1.74.0 libboost-locale1.74.0 libboost-thread1.74.0
#   libbsh-java libcdparanoia0 libcdr-0.1-1 libclucene-contribs1v5
#   libclucene-core1v5 libcolamd2 libe-book-0.1-1 libel-api-java libeot0
#   libepubgen-0.1-1 libetonyek-0.1-1 libexttextcat-2.0-0 libexttextcat-data
#   libfbclient2 libfreehand-0.1-1 libgpgme11 libgpgmepp6 libgstreamer-gl1.0-0
#   libgstreamer-plugins-base1.0-0 libgtk-3-0 libgtk-3-bin libgtk-3-common
#   libgudev-1.0-0 libharfbuzz-icu0 libhsqldb1.8.0-java libhunspell-1.7-0
#   libhyphen0 libib-util libjsp-api-java liblangtag-common liblangtag1
#   liblibreoffice-java libmhash2 libmspub-0.1-1 libmwaw-0.3-3 libmythes-1.2-0
#   libodfgen-0.1-1 liborc-0.4-0 liborcus-0.17-0 liborcus-parser-0.17-0
#   libpagemaker-0.0-0 libraptor2-0 librasqal3 librdf0 libreoffice
#   libreoffice-base libreoffice-base-core libreoffice-base-drivers
#   libreoffice-calc libreoffice-common libreoffice-core libreoffice-draw
#   libreoffice-gnome libreoffice-gtk3 libreoffice-impress
#   libreoffice-java-common libreoffice-math libreoffice-nlpsolver
#   libreoffice-report-builder libreoffice-report-builder-bin
#   libreoffice-script-provider-bsh libreoffice-script-provider-js
#   libreoffice-script-provider-python libreoffice-sdbc-firebird
#   libreoffice-sdbc-hsqldb libreoffice-sdbc-mysql libreoffice-sdbc-postgresql
#   libreoffice-style-colibre libreoffice-style-elementary
#   libreoffice-style-yaru libreoffice-wiki-publisher libreoffice-writer
#   librevenge-0.0-0 librsvg2-common libservlet-api-java libservlet3.1-java
#   libsuitesparseconfig5 libtext-iconv-perl libtommath1 libuno-cppu3
#   libuno-cppuhelpergcc3-3 libuno-purpenvhelpergcc3-3 libuno-sal3
#   libuno-salhelpergcc3-3 libunoloader-java libvisio-0.1-1 libvisual-0.4-0
#   libwebsocket-api-java libwpd-0.10-10 libwpg-0.3-3 libwps-0.4-4
#   libxcomposite1 libxmlsec1 libxmlsec1-nss libxtst6 libxxf86dga1 libyajl2
#   lp-solve openjdk-11-jre openjdk-11-jre-headless poppler-data poppler-utils
#   python3-uno session-migration uno-libs-private ure ure-java x11-utils
# 0 upgraded, 152 newly installed, 0 to remove and 41 not upgraded.
# Need to get 508 MB of archives.
# After this operation, 1,441 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-unfonts-core all 1:1.0.2-080608-16 [14.9 MB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 fonts-opensymbol all 2:102.12+LibO7.3.7-0ubuntu0.22.04.10 [103 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-style-colibre all 1:7.3.7-0ubuntu0.22.04.10 [1,294 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-sal3 amd64 1:7.3.7-0ubuntu0.22.04.10 [197 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-salhelpergcc3-3 amd64 1:7.3.7-0ubuntu0.22.04.10 [17.0 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-cppu3 amd64 1:7.3.7-0ubuntu0.22.04.10 [87.8 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 uno-libs-private amd64 1:7.3.7-0ubuntu0.22.04.10 [232 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblangtag-common all 0.6.3-2ubuntu1 [193 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblangtag1 amd64 0.6.3-2ubuntu1 [53.8 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-cppuhelpergcc3-3 amd64 1:7.3.7-0ubuntu0.22.04.10 [343 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-purpenvhelpergcc3-3 amd64 1:7.3.7-0ubuntu0.22.04.10 [15.8 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ure amd64 1:7.3.7-0ubuntu0.22.04.10 [1,312 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-common all 1:7.3.7-0ubuntu0.22.04.10 [23.4 MB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libabsl20210324 amd64 0~20210324.2-2ubuntu0.2 [386 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-thread1.74.0 amd64 1.74.0-14ubuntu3 [262 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-locale1.74.0 amd64 1.74.0-14ubuntu3 [413 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclucene-core1v5 amd64 2.3.3.4+dfsg-1ubuntu5 [530 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclucene-contribs1v5 amd64 2.3.3.4+dfsg-1ubuntu5 [96.7 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libeot0 amd64 0.01-5build2 [28.5 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libexttextcat-data all 3.4.5-1build2 [179 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libexttextcat-2.0-0 amd64 3.4.5-1build2 [13.7 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgpgme11 amd64 1.16.0-1.2ubuntu4.2 [136 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgpgmepp6 amd64 1.16.0-1.2ubuntu4.2 [109 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 liborc-0.4-0 amd64 1:0.4.32-2ubuntu0.1 [228 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-plugins-base1.0-0 amd64 1.20.1-1ubuntu0.5 [848 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libharfbuzz-icu0 amd64 2.7.4-1ubuntu3.2 [5,890 B]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhunspell-1.7-0 amd64 1.7.0-4build1 [175 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhyphen0 amd64 2.8.8-7build2 [28.2 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmythes-1.2-0 amd64 2:1.2.4-4build1 [9,352 B]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-filesystem1.74.0 amd64 1.74.0-14ubuntu3 [264 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-iostreams1.74.0 amd64 1.74.0-14ubuntu3 [245 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 liborcus-parser-0.17-0 amd64 0.17.2-2 [107 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 liborcus-0.17-0 amd64 0.17.2-2 [393 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libyajl2 amd64 2.1.0-3ubuntu0.22.04.1 [21.0 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libraptor2-0 amd64 2.0.15-0ubuntu4.1 [172 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmhash2 amd64 0.9.9.9-9build2 [95.9 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 librasqal3 amd64 0.9.33-0.2ubuntu1 [193 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 librdf0 amd64 1.0.17-1.1ubuntu3 [106 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 librevenge-0.0-0 amd64 0.0.4-6ubuntu7 [209 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmlsec1 amd64 1.2.33-1build2 [139 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmlsec1-nss amd64 1.2.33-1build2 [67.7 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-core amd64 1:7.3.7-0ubuntu0.22.04.10 [40.5 MB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-base-core amd64 1:7.3.7-0ubuntu0.22.04.10 [974 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-base-drivers amd64 1:7.3.7-0ubuntu0.22.04.10 [602 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-base amd64 1:7.3.7-0ubuntu0.22.04.10 [1,725 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 poppler-data all 0.4.11-1 [2,171 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtext-iconv-perl amd64 1.7-7build3 [14.3 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 apparmor amd64 3.0.4-2ubuntu2.4 [598 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatspi2.0-0 amd64 2.44.0-3 [80.9 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/main amd64 session-migration amd64 0.3.6 [9,774 B]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/main amd64 gsettings-desktop-schemas all 42.0-1ubuntu1 [31.1 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/main amd64 at-spi2-core amd64 2.44.0-3 [54.4 kB]
# Ign:54 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre-headless amd64 11.0.28+6-1ubuntu1~22.04.1
# Get:55 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# Ign:56 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.28+6-1ubuntu1~22.04.1
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre amd64 2:1.11-72build2 [896 B]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/main amd64 dictionaries-common all 1.28.14 [185 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/universe amd64 firebird3.0-common-doc all 3.0.8.33535.ds4-1ubuntu2 [26.8 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/universe amd64 firebird3.0-common all 3.0.8.33535.ds4-1ubuntu2 [15.5 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtommath1 amd64 1.2.0-6ubuntu0.22.04.1 [56.5 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfbclient2 amd64 3.0.8.33535.ds4-1ubuntu2 [512 kB]
# Err:54 http://security.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre-headless amd64 11.0.28+6-1ubuntu1~22.04.1
#   404  Not Found [IP: 91.189.92.24 80]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libib-util amd64 3.0.8.33535.ds4-1ubuntu2 [3,378 B]
# Get:64 http://archive.ubuntu.com/ubuntu jammy/universe amd64 firebird3.0-server-core amd64 3.0.8.33535.ds4-1ubuntu2 [2,533 kB]
# Err:56 http://security.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.28+6-1ubuntu1~22.04.1
#   404  Not Found [IP: 91.189.92.24 80]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/universe amd64 firebird3.0-utils amd64 3.0.8.33535.ds4-1ubuntu2 [872 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-crosextra-caladea all 20130214-2.1 [82.4 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-crosextra-carlito all 20130920-1.1 [743 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-dejavu all 2.37-2build1 [3,192 B]
# Get:71 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-liberation2 all 2.1.5-1 [1,614 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-linuxlibertine all 5.3.0-6 [1,627 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-cjk all 1:20220127+repack1-1 [61.2 MB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-cjk-extra all 1:20220127+repack1-1 [145 MB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-core all 20201225-1build1 [12.2 MB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-noto-extra all 20201225-1build1 [72.4 MB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-mono all 20201225-1build1 [397 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-ui-core all 20201225-1build1 [1,420 kB]
# Get:80 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-sil-gentium all 20081126:1.03-4 [245 kB]
# Get:81 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-sil-gentium-basic all 1.102-1.1 [384 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:83 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-gl1.0-0 amd64 1.20.1-1ubuntu0.5 [204 kB]
# Get:84 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-gl amd64 1.20.1-1ubuntu0.5 [125 kB]
# Get:85 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-data all 2.36.0-3build1 [2,824 B]
# Get:86 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-0 amd64 2.36.0-3build1 [51.9 kB]
# Get:87 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-bridge2.0-0 amd64 2.38.0-3 [66.6 kB]
# Get:88 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcomposite1 amd64 1:0.4.5-1build2 [7,192 B]
# Get:89 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-common all 3.24.33-1ubuntu2.2 [239 kB]
# Get:90 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-0 amd64 3.24.33-1ubuntu2.2 [3,053 kB]
# Get:91 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-gtk3 amd64 1.20.3-0ubuntu1.4 [33.3 kB]
# Get:92 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdparanoia0 amd64 3.10.2+debian-14build2 [49.3 kB]
# Get:93 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvisual-0.4-0 amd64 0.4.0-17build2 [108 kB]
# Get:94 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-plugins-base amd64 1.20.1-1ubuntu0.5 [712 kB]
# Get:95 http://archive.ubuntu.com/ubuntu jammy/main amd64 hunspell-en-us all 1:2020.12.07-2 [280 kB]
# Get:96 http://archive.ubuntu.com/ubuntu jammy/main amd64 libabw-0.1-1 amd64 0.1.3-1build3 [102 kB]
# Get:97 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:98 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:99 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:100 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:101 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbsh-java all 2.0b4-20 [289 kB]
# Get:102 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdr-0.1-1 amd64 0.1.6-2build2 [392 kB]
# Get:103 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsuitesparseconfig5 amd64 1:5.10.1+dfsg-4build1 [10.4 kB]
# Get:104 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcolamd2 amd64 1:5.10.1+dfsg-4build1 [18.0 kB]
# Get:105 http://archive.ubuntu.com/ubuntu jammy/main amd64 libe-book-0.1-1 amd64 0.1.3-2build2 [148 kB]
# Get:106 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libel-api-java all 3.0.0-3 [64.9 kB]
# Get:107 http://archive.ubuntu.com/ubuntu jammy/main amd64 libepubgen-0.1-1 amd64 0.1.1-1ubuntu5 [120 kB]
# Get:108 http://archive.ubuntu.com/ubuntu jammy/main amd64 libetonyek-0.1-1 amd64 0.1.10-3build1 [637 kB]
# Get:109 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfreehand-0.1-1 amd64 0.1.2-3build2 [272 kB]
# Get:110 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-bin amd64 3.24.33-1ubuntu2.2 [69.6 kB]
# Get:111 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libservlet-api-java all 4.0.1-2 [81.0 kB]
# Get:112 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjsp-api-java all 2.3.4-3 [53.7 kB]
# Get:113 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwebsocket-api-java all 1.1-2 [40.1 kB]
# Get:114 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libservlet3.1-java all 1:4.0.1-2 [9,276 B]
# Get:115 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhsqldb1.8.0-java all 1.8.0.10+dfsg-11 [765 kB]
# Get:116 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libunoloader-java all 1:7.3.7-0ubuntu0.22.04.10 [13.0 kB]
# Get:117 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ure-java amd64 1:7.3.7-0ubuntu0.22.04.10 [83.5 kB]
# Get:118 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 liblibreoffice-java all 1:7.3.7-0ubuntu0.22.04.10 [1,604 kB]
# Get:119 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmspub-0.1-1 amd64 0.1.4-3build3 [144 kB]
# Get:120 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmwaw-0.3-3 amd64 0.3.21-1build1 [2,375 kB]
# Get:121 http://archive.ubuntu.com/ubuntu jammy/main amd64 libodfgen-0.1-1 amd64 0.1.8-2build2 [245 kB]
# Get:122 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpagemaker-0.0-0 amd64 0.0.4-1build3 [55.9 kB]
# Get:123 http://archive.ubuntu.com/ubuntu jammy/main amd64 lp-solve amd64 5.5.2.5-2build2 [315 kB]
# Get:124 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwps-0.4-4 amd64 0.4.12-2build1 [812 kB]
# Get:125 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-calc amd64 1:7.3.7-0ubuntu0.22.04.10 [8,426 kB]
# Get:126 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvisio-0.1-1 amd64 0.1.7-1build5 [238 kB]
# Get:127 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwpd-0.10-10 amd64 0.10.3-2build1 [209 kB]
# Get:128 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwpg-0.3-3 amd64 0.3.3-1build3 [49.9 kB]
# Get:129 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-draw amd64 1:7.3.7-0ubuntu0.22.04.10 [3,228 kB]
# Get:130 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-impress amd64 1:7.3.7-0ubuntu0.22.04.10 [1,359 kB]
# Get:131 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-math amd64 1:7.3.7-0ubuntu0.22.04.10 [597 kB]
# Get:132 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-report-builder-bin amd64 1:7.3.7-0ubuntu0.22.04.10 [971 kB]
# Get:133 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-writer amd64 1:7.3.7-0ubuntu0.22.04.10 [10.3 MB]
# Get:134 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-uno amd64 1:7.3.7-0ubuntu0.22.04.10 [148 kB]
# Get:135 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice amd64 1:7.3.7-0ubuntu0.22.04.10 [12.9 kB]
# Get:136 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-gnome amd64 1:7.3.7-0ubuntu0.22.04.10 [72.9 kB]
# Get:137 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-gtk3 amd64 1:7.3.7-0ubuntu0.22.04.10 [509 kB]
# Get:138 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-java-common all 1:7.3.7-0ubuntu0.22.04.10 [621 kB]
# Get:139 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-report-builder all 1:7.3.7-0ubuntu0.22.04.10 [2,112 kB]
# Get:140 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-script-provider-bsh all 1:7.3.7-0ubuntu0.22.04.10 [42.3 kB]
# Get:141 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-script-provider-js all 1:7.3.7-0ubuntu0.22.04.10 [645 kB]
# Get:142 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-script-provider-python all 1:7.3.7-0ubuntu0.22.04.10 [16.5 kB]
# Get:143 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-sdbc-firebird amd64 1:7.3.7-0ubuntu0.22.04.10 [176 kB]
# Get:144 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-sdbc-hsqldb amd64 1:7.3.7-0ubuntu0.22.04.10 [135 kB]
# Get:145 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-sdbc-mysql amd64 1:7.3.7-0ubuntu0.22.04.10 [123 kB]
# Get:146 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-sdbc-postgresql amd64 1:7.3.7-0ubuntu0.22.04.10 [279 kB]
# Get:147 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-style-elementary all 1:7.3.7-0ubuntu0.22.04.10 [8,020 kB]
# Get:148 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-style-yaru all 1:7.3.7-0ubuntu0.22.04.10 [3,761 kB]
# Get:149 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-wiki-publisher all 1.2.0+LibO7.3.7-0ubuntu0.22.04.10 [7,930 B]
# Get:150 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Get:151 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.12 [186 kB]
# Get:152 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-nlpsolver all 0.9+LibO7.3.7-0ubuntu0.22.04.10 [7,986 B]
# Fetched 465 MB in 14s (32.8 MB/s)
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/main/o/openjdk-lts/openjdk-11-jre-headless_11.0.28%2b6-1ubuntu1%7e22.04.1_amd64.deb  404  Not Found [IP: 91.189.92.24 80]
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/main/o/openjdk-lts/openjdk-11-jre_11.0.28%2b6-1ubuntu1%7e22.04.1_amd64.deb  404  Not Found [IP: 91.189.92.24 80]
# E: Unable to fetch some archives, maybe run apt-get update or try with --fix-missing?
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   apparmor dictionaries-common fonts-liberation2 fonts-opensymbol
#   gstreamer1.0-plugins-base hunspell-en-us libabsl20210324
#   libboost-filesystem1.74.0 libboost-iostreams1.74.0 libboost-locale1.74.0
#   libboost-thread1.74.0 libcdparanoia0 libcdr-0.1-1 libclucene-contribs1v5
#   libclucene-core1v5 libeot0 libetonyek-0.1-1 libexttextcat-2.0-0
#   libexttextcat-data libfreehand-0.1-1 libgpgme11 libgpgmepp6
#   libgstreamer-plugins-base1.0-0 libharfbuzz-icu0 libhunspell-1.7-0 libhyphen0
#   liblangtag-common liblangtag1 libmhash2 libmspub-0.1-1 libmwaw-0.3-3
#   libmythes-1.2-0 libodfgen-0.1-1 liborc-0.4-0 liborcus-0.17-0
#   liborcus-parser-0.17-0 libpagemaker-0.0-0 libraptor2-0 librasqal3 librdf0
#   libreoffice-core libreoffice-draw libreoffice-style-colibre librevenge-0.0-0
#   libtext-iconv-perl libuno-cppu3 libuno-cppuhelpergcc3-3
#   libuno-purpenvhelpergcc3-3 libuno-sal3 libuno-salhelpergcc3-3 libvisio-0.1-1
#   libvisual-0.4-0 libwpd-0.10-10 libwpg-0.3-3 libxmlsec1 libxmlsec1-nss
#   libyajl2 poppler-data python3-uno uno-libs-private ure
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils ispell | aspell | hunspell wordlist
#   fonts-noto-cjk-extra gvfs hunspell openoffice.org-hunspell
#   | openoffice.org-core libvisual-0.4-plugins raptor2-utils rasqal-utils
#   librdf-storage-postgresql librdf-storage-mysql librdf-storage-sqlite
#   librdf-storage-virtuoso redland-utils gstreamer1.0-plugins-good
#   gstreamer1.0-plugins-ugly gstreamer1.0-plugins-bad gstreamer1.0-libav bluez
#   ghostscript fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming
# The following NEW packages will be installed:
#   apparmor dictionaries-common fonts-liberation2 fonts-nanum fonts-noto-cjk
#   fonts-opensymbol gstreamer1.0-plugins-base hunspell-en-us libabsl20210324
#   libboost-filesystem1.74.0 libboost-iostreams1.74.0 libboost-locale1.74.0
#   libboost-thread1.74.0 libcdparanoia0 libcdr-0.1-1 libclucene-contribs1v5
#   libclucene-core1v5 libeot0 libetonyek-0.1-1 libexttextcat-2.0-0
#   libexttextcat-data libfreehand-0.1-1 libgpgme11 libgpgmepp6
#   libgstreamer-plugins-base1.0-0 libharfbuzz-icu0 libhunspell-1.7-0 libhyphen0
#   liblangtag-common liblangtag1 libmhash2 libmspub-0.1-1 libmwaw-0.3-3
#   libmythes-1.2-0 libodfgen-0.1-1 liborc-0.4-0 liborcus-0.17-0
#   liborcus-parser-0.17-0 libpagemaker-0.0-0 libraptor2-0 librasqal3 librdf0
#   libreoffice-common libreoffice-core libreoffice-draw libreoffice-impress
#   libreoffice-style-colibre librevenge-0.0-0 libtext-iconv-perl libuno-cppu3
#   libuno-cppuhelpergcc3-3 libuno-purpenvhelpergcc3-3 libuno-sal3
#   libuno-salhelpergcc3-3 libvisio-0.1-1 libvisual-0.4-0 libwpd-0.10-10
#   libwpg-0.3-3 libxmlsec1 libxmlsec1-nss libyajl2 poppler-data poppler-utils
#   python3-uno uno-libs-private ure
# 0 upgraded, 66 newly installed, 0 to remove and 41 not upgraded.
# Need to get 0 B/160 MB of archives.
# After this operation, 430 MB of additional disk space will be used.
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package poppler-data.
# (Reading database ... 121713 files and directories currently installed.)
# Preparing to unpack .../00-poppler-data_0.4.11-1_all.deb ...
# Unpacking poppler-data (0.4.11-1) ...
# Selecting previously unselected package libtext-iconv-perl.
# Preparing to unpack .../01-libtext-iconv-perl_1.7-7build3_amd64.deb ...
# Unpacking libtext-iconv-perl (1.7-7build3) ...
# Selecting previously unselected package apparmor.
# Preparing to unpack .../02-apparmor_3.0.4-2ubuntu2.4_amd64.deb ...
# Unpacking apparmor (3.0.4-2ubuntu2.4) ...
# Selecting previously unselected package dictionaries-common.
# Preparing to unpack .../03-dictionaries-common_1.28.14_all.deb ...
# Adding 'diversion of /usr/share/dict/words to /usr/share/dict/words.pre-dictionaries-common by dictionaries-common'
# Unpacking dictionaries-common (1.28.14) ...
# Selecting previously unselected package fonts-liberation2.
# Preparing to unpack .../04-fonts-liberation2_2.1.5-1_all.deb ...
# Unpacking fonts-liberation2 (2.1.5-1) ...
# Selecting previously unselected package fonts-nanum.
# Preparing to unpack .../05-fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Selecting previously unselected package fonts-noto-cjk.
# Preparing to unpack .../06-fonts-noto-cjk_1%3a20220127+repack1-1_all.deb ...
# Unpacking fonts-noto-cjk (1:20220127+repack1-1) ...
# Selecting previously unselected package fonts-opensymbol.
# Preparing to unpack .../07-fonts-opensymbol_2%3a102.12+LibO7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking fonts-opensymbol (2:102.12+LibO7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libcdparanoia0:amd64.
# Preparing to unpack .../08-libcdparanoia0_3.10.2+debian-14build2_amd64.deb ...
# Unpacking libcdparanoia0:amd64 (3.10.2+debian-14build2) ...
# Selecting previously unselected package liborc-0.4-0:amd64.
# Preparing to unpack .../09-liborc-0.4-0_1%3a0.4.32-2ubuntu0.1_amd64.deb ...
# Unpacking liborc-0.4-0:amd64 (1:0.4.32-2ubuntu0.1) ...
# Selecting previously unselected package libgstreamer-plugins-base1.0-0:amd64.
# Preparing to unpack .../10-libgstreamer-plugins-base1.0-0_1.20.1-1ubuntu0.5_amd64.deb ...
# Unpacking libgstreamer-plugins-base1.0-0:amd64 (1.20.1-1ubuntu0.5) ...
# Selecting previously unselected package libvisual-0.4-0:amd64.
# Preparing to unpack .../11-libvisual-0.4-0_0.4.0-17build2_amd64.deb ...
# Unpacking libvisual-0.4-0:amd64 (0.4.0-17build2) ...
# Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# Preparing to unpack .../12-gstreamer1.0-plugins-base_1.20.1-1ubuntu0.5_amd64.deb ...
# Unpacking gstreamer1.0-plugins-base:amd64 (1.20.1-1ubuntu0.5) ...
# Selecting previously unselected package hunspell-en-us.
# Preparing to unpack .../13-hunspell-en-us_1%3a2020.12.07-2_all.deb ...
# Unpacking hunspell-en-us (1:2020.12.07-2) ...
# Selecting previously unselected package libabsl20210324:amd64.
# Preparing to unpack .../14-libabsl20210324_0~20210324.2-2ubuntu0.2_amd64.deb ...
# Unpacking libabsl20210324:amd64 (0~20210324.2-2ubuntu0.2) ...
# Selecting previously unselected package libboost-filesystem1.74.0:amd64.
# Preparing to unpack .../15-libboost-filesystem1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-filesystem1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-iostreams1.74.0:amd64.
# Preparing to unpack .../16-libboost-iostreams1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-iostreams1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-thread1.74.0:amd64.
# Preparing to unpack .../17-libboost-thread1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-thread1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-locale1.74.0:amd64.
# Preparing to unpack .../18-libboost-locale1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-locale1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package librevenge-0.0-0:amd64.
# Preparing to unpack .../19-librevenge-0.0-0_0.0.4-6ubuntu7_amd64.deb ...
# Unpacking librevenge-0.0-0:amd64 (0.0.4-6ubuntu7) ...
# Selecting previously unselected package libcdr-0.1-1:amd64.
# Preparing to unpack .../20-libcdr-0.1-1_0.1.6-2build2_amd64.deb ...
# Unpacking libcdr-0.1-1:amd64 (0.1.6-2build2) ...
# Selecting previously unselected package libclucene-core1v5:amd64.
# Preparing to unpack .../21-libclucene-core1v5_2.3.3.4+dfsg-1ubuntu5_amd64.deb ...
# Unpacking libclucene-core1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Selecting previously unselected package libclucene-contribs1v5:amd64.
# Preparing to unpack .../22-libclucene-contribs1v5_2.3.3.4+dfsg-1ubuntu5_amd64.deb ...
# Unpacking libclucene-contribs1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Selecting previously unselected package libeot0:amd64.
# Preparing to unpack .../23-libeot0_0.01-5build2_amd64.deb ...
# Unpacking libeot0:amd64 (0.01-5build2) ...
# Selecting previously unselected package liblangtag-common.
# Preparing to unpack .../24-liblangtag-common_0.6.3-2ubuntu1_all.deb ...
# Unpacking liblangtag-common (0.6.3-2ubuntu1) ...
# Selecting previously unselected package liblangtag1:amd64.
# Preparing to unpack .../25-liblangtag1_0.6.3-2ubuntu1_amd64.deb ...
# Unpacking liblangtag1:amd64 (0.6.3-2ubuntu1) ...
# Selecting previously unselected package libetonyek-0.1-1:amd64.
# Preparing to unpack .../26-libetonyek-0.1-1_0.1.10-3build1_amd64.deb ...
# Unpacking libetonyek-0.1-1:amd64 (0.1.10-3build1) ...
# Selecting previously unselected package libexttextcat-data.
# Preparing to unpack .../27-libexttextcat-data_3.4.5-1build2_all.deb ...
# Unpacking libexttextcat-data (3.4.5-1build2) ...
# Selecting previously unselected package libexttextcat-2.0-0:amd64.
# Preparing to unpack .../28-libexttextcat-2.0-0_3.4.5-1build2_amd64.deb ...
# Unpacking libexttextcat-2.0-0:amd64 (3.4.5-1build2) ...
# Selecting previously unselected package libfreehand-0.1-1.
# Preparing to unpack .../29-libfreehand-0.1-1_0.1.2-3build2_amd64.deb ...
# Unpacking libfreehand-0.1-1 (0.1.2-3build2) ...
# Selecting previously unselected package libgpgme11:amd64.
# Preparing to unpack .../30-libgpgme11_1.16.0-1.2ubuntu4.2_amd64.deb ...
# Unpacking libgpgme11:amd64 (1.16.0-1.2ubuntu4.2) ...
# Selecting previously unselected package libgpgmepp6:amd64.
# Preparing to unpack .../31-libgpgmepp6_1.16.0-1.2ubuntu4.2_amd64.deb ...
# Unpacking libgpgmepp6:amd64 (1.16.0-1.2ubuntu4.2) ...
# Selecting previously unselected package libharfbuzz-icu0:amd64.
# Preparing to unpack .../32-libharfbuzz-icu0_2.7.4-1ubuntu3.2_amd64.deb ...
# Unpacking libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.2) ...
# Selecting previously unselected package libhunspell-1.7-0:amd64.
# Preparing to unpack .../33-libhunspell-1.7-0_1.7.0-4build1_amd64.deb ...
# Unpacking libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Selecting previously unselected package libhyphen0:amd64.
# Preparing to unpack .../34-libhyphen0_2.8.8-7build2_amd64.deb ...
# Unpacking libhyphen0:amd64 (2.8.8-7build2) ...
# Selecting previously unselected package libmhash2:amd64.
# Preparing to unpack .../35-libmhash2_0.9.9.9-9build2_amd64.deb ...
# Unpacking libmhash2:amd64 (0.9.9.9-9build2) ...
# Selecting previously unselected package libmspub-0.1-1:amd64.
# Preparing to unpack .../36-libmspub-0.1-1_0.1.4-3build3_amd64.deb ...
# Unpacking libmspub-0.1-1:amd64 (0.1.4-3build3) ...
# Selecting previously unselected package libmwaw-0.3-3:amd64.
# Preparing to unpack .../37-libmwaw-0.3-3_0.3.21-1build1_amd64.deb ...
# Unpacking libmwaw-0.3-3:amd64 (0.3.21-1build1) ...
# Selecting previously unselected package libmythes-1.2-0:amd64.
# Preparing to unpack .../38-libmythes-1.2-0_2%3a1.2.4-4build1_amd64.deb ...
# Unpacking libmythes-1.2-0:amd64 (2:1.2.4-4build1) ...
# Selecting previously unselected package libodfgen-0.1-1:amd64.
# Preparing to unpack .../39-libodfgen-0.1-1_0.1.8-2build2_amd64.deb ...
# Unpacking libodfgen-0.1-1:amd64 (0.1.8-2build2) ...
# Selecting previously unselected package liborcus-parser-0.17-0:amd64.
# Preparing to unpack .../40-liborcus-parser-0.17-0_0.17.2-2_amd64.deb ...
# Unpacking liborcus-parser-0.17-0:amd64 (0.17.2-2) ...
# Selecting previously unselected package liborcus-0.17-0:amd64.
# Preparing to unpack .../41-liborcus-0.17-0_0.17.2-2_amd64.deb ...
# Unpacking liborcus-0.17-0:amd64 (0.17.2-2) ...
# Selecting previously unselected package libpagemaker-0.0-0:amd64.
# Preparing to unpack .../42-libpagemaker-0.0-0_0.0.4-1build3_amd64.deb ...
# Unpacking libpagemaker-0.0-0:amd64 (0.0.4-1build3) ...
# Selecting previously unselected package libyajl2:amd64.
# Preparing to unpack .../43-libyajl2_2.1.0-3ubuntu0.22.04.1_amd64.deb ...
# Unpacking libyajl2:amd64 (2.1.0-3ubuntu0.22.04.1) ...
# Selecting previously unselected package libraptor2-0:amd64.
# Preparing to unpack .../44-libraptor2-0_2.0.15-0ubuntu4.1_amd64.deb ...
# Unpacking libraptor2-0:amd64 (2.0.15-0ubuntu4.1) ...
# Selecting previously unselected package librasqal3:amd64.
# Preparing to unpack .../45-librasqal3_0.9.33-0.2ubuntu1_amd64.deb ...
# Unpacking librasqal3:amd64 (0.9.33-0.2ubuntu1) ...
# Selecting previously unselected package librdf0:amd64.
# Preparing to unpack .../46-librdf0_1.0.17-1.1ubuntu3_amd64.deb ...
# Unpacking librdf0:amd64 (1.0.17-1.1ubuntu3) ...
# Selecting previously unselected package libreoffice-style-colibre.
# Preparing to unpack .../47-libreoffice-style-colibre_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-style-colibre (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libuno-sal3.
# Preparing to unpack .../48-libuno-sal3_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libuno-sal3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libuno-salhelpergcc3-3.
# Preparing to unpack .../49-libuno-salhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libuno-salhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libuno-cppu3.
# Preparing to unpack .../50-libuno-cppu3_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libuno-cppu3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package uno-libs-private.
# Preparing to unpack .../51-uno-libs-private_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking uno-libs-private (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libuno-cppuhelpergcc3-3.
# Preparing to unpack .../52-libuno-cppuhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libuno-cppuhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libuno-purpenvhelpergcc3-3.
# Preparing to unpack .../53-libuno-purpenvhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libuno-purpenvhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package ure.
# Preparing to unpack .../54-ure_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking ure (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-common.
# Preparing to unpack .../55-libreoffice-common_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-common (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libxmlsec1:amd64.
# Preparing to unpack .../56-libxmlsec1_1.2.33-1build2_amd64.deb ...
# Unpacking libxmlsec1:amd64 (1.2.33-1build2) ...
# Selecting previously unselected package libxmlsec1-nss:amd64.
# Preparing to unpack .../57-libxmlsec1-nss_1.2.33-1build2_amd64.deb ...
# Unpacking libxmlsec1-nss:amd64 (1.2.33-1build2) ...
# Selecting previously unselected package libreoffice-core.
# Preparing to unpack .../58-libreoffice-core_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-core (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libvisio-0.1-1:amd64.
# Preparing to unpack .../59-libvisio-0.1-1_0.1.7-1build5_amd64.deb ...
# Unpacking libvisio-0.1-1:amd64 (0.1.7-1build5) ...
# Selecting previously unselected package libwpd-0.10-10:amd64.
# Preparing to unpack .../60-libwpd-0.10-10_0.10.3-2build1_amd64.deb ...
# Unpacking libwpd-0.10-10:amd64 (0.10.3-2build1) ...
# Selecting previously unselected package libwpg-0.3-3:amd64.
# Preparing to unpack .../61-libwpg-0.3-3_0.3.3-1build3_amd64.deb ...
# Unpacking libwpg-0.3-3:amd64 (0.3.3-1build3) ...
# Selecting previously unselected package libreoffice-draw.
# Preparing to unpack .../62-libreoffice-draw_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-draw (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-impress.
# Preparing to unpack .../63-libreoffice-impress_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-impress (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package poppler-utils.
# Preparing to unpack .../64-poppler-utils_22.02.0-2ubuntu0.12_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.12) ...
# Selecting previously unselected package python3-uno.
# Preparing to unpack .../65-python3-uno_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking python3-uno (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libtext-iconv-perl (1.7-7build3) ...
# Setting up libcdparanoia0:amd64 (3.10.2+debian-14build2) ...
# Setting up libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.2) ...
# Setting up libhyphen0:amd64 (2.8.8-7build2) ...
# Setting up dictionaries-common (1.28.14) ...
# Setting up libvisual-0.4-0:amd64 (0.4.0-17build2) ...
# Setting up libboost-iostreams1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Setting up fonts-nanum (20200506-1) ...
# Setting up fonts-noto-cjk (1:20220127+repack1-1) ...
# Setting up libyajl2:amd64 (2.1.0-3ubuntu0.22.04.1) ...
# Setting up libuno-sal3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libboost-filesystem1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Setting up libeot0:amd64 (0.01-5build2) ...
# Setting up libgpgme11:amd64 (1.16.0-1.2ubuntu4.2) ...
# Setting up librevenge-0.0-0:amd64 (0.0.4-6ubuntu7) ...
# Setting up poppler-data (0.4.11-1) ...
# Setting up apparmor (3.0.4-2ubuntu2.4) ...
# Created symlink /etc/systemd/system/sysinit.target.wants/apparmor.service → /lib/systemd/system/apparmor.service.
# Setting up libreoffice-style-colibre (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up liborcus-parser-0.17-0:amd64 (0.17.2-2) ...
# Setting up fonts-liberation2 (2.1.5-1) ...
# Setting up liborc-0.4-0:amd64 (1:0.4.32-2ubuntu0.1) ...
# Setting up libfreehand-0.1-1 (0.1.2-3build2) ...
# Setting up libclucene-core1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Setting up libabsl20210324:amd64 (0~20210324.2-2ubuntu0.2) ...
# Setting up libmhash2:amd64 (0.9.9.9-9build2) ...
# Setting up libmythes-1.2-0:amd64 (2:1.2.4-4build1) ...
# Setting up libexttextcat-data (3.4.5-1build2) ...
# Setting up hunspell-en-us (1:2020.12.07-2) ...
# Setting up libuno-salhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.12) ...
# Setting up liblangtag-common (0.6.3-2ubuntu1) ...
# Setting up libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Setting up libxmlsec1:amd64 (1.2.33-1build2) ...
# Setting up libwpd-0.10-10:amd64 (0.10.3-2build1) ...
# Setting up fonts-opensymbol (2:102.12+LibO7.3.7-0ubuntu0.22.04.10) ...
# Setting up libodfgen-0.1-1:amd64 (0.1.8-2build2) ...
# Setting up libvisio-0.1-1:amd64 (0.1.7-1build5) ...
# Setting up libboost-thread1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Setting up libexttextcat-2.0-0:amd64 (3.4.5-1build2) ...
# Setting up libgpgmepp6:amd64 (1.16.0-1.2ubuntu4.2) ...
# Setting up libmspub-0.1-1:amd64 (0.1.4-3build3) ...
# Setting up libraptor2-0:amd64 (2.0.15-0ubuntu4.1) ...
# Setting up libgstreamer-plugins-base1.0-0:amd64 (1.20.1-1ubuntu0.5) ...
# Setting up libpagemaker-0.0-0:amd64 (0.0.4-1build3) ...
# Setting up libmwaw-0.3-3:amd64 (0.3.21-1build1) ...
# Setting up libcdr-0.1-1:amd64 (0.1.6-2build2) ...
# Setting up liblangtag1:amd64 (0.6.3-2ubuntu1) ...
# Setting up liborcus-0.17-0:amd64 (0.17.2-2) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.20.1-1ubuntu0.5) ...
# Setting up libuno-cppu3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libclucene-contribs1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Setting up libwpg-0.3-3:amd64 (0.3.3-1build3) ...
# Setting up libxmlsec1-nss:amd64 (1.2.33-1build2) ...
# Setting up libboost-locale1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Setting up libuno-purpenvhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up uno-libs-private (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up librasqal3:amd64 (0.9.33-0.2ubuntu1) ...
# Setting up libetonyek-0.1-1:amd64 (0.1.10-3build1) ...
# Setting up librdf0:amd64 (1.0.17-1.1ubuntu3) ...
# Setting up libuno-cppuhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up ure (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-common (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/main.xcd with new version
#
# Creating config file /etc/libreoffice/registry/pdfimport.xcd with new version
#
# Creating config file /etc/libreoffice/registry/xsltfilter.xcd with new version
#
# Creating config file /etc/libreoffice/registry/lingucomponent.xcd with new version
#
# Creating config file /etc/libreoffice/registry/Langpack-en-US.xcd with new version
#
# Creating config file /etc/libreoffice/registry/res/fcfg_langpack_en-US.xcd with new version
# Setting up libreoffice-core (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-draw (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/draw.xcd with new version
#
# Creating config file /etc/libreoffice/registry/graphicfilter.xcd with new version
# Setting up libreoffice-impress (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/impress.xcd with new version
#
# Creating config file /etc/libreoffice/registry/ogltrans.xcd with new version
# Setting up python3-uno (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/pyuno.xcd with new version
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for shared-mime-info (2.1-2) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for dictionaries-common (1.28.14) ...
# Generating locales (this might take a while)...
#   ko_KR.UTF-8... done
# Generation complete.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 4 dirs
# /usr/share/fonts/cMap: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap: caching, new cache contents: 0 fonts, 5 dirs
# /usr/share/fonts/cmap/adobe-cns1: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap/adobe-gb1: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap/adobe-japan1: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap/adobe-japan2: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap/adobe-korea1: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/opentype: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/opentype/noto: caching, new cache contents: 30 fonts, 0 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 5 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation2: caching, new cache contents: 12 fonts, 0 dirs
# /usr/share/fonts/truetype/libreoffice: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/cMap: skipping, looped directory detected
# /usr/share/fonts/cmap: skipping, looped directory detected
# /usr/share/fonts/opentype: skipping, looped directory detected
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-cns1: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-gb1: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-japan1: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-japan2: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-korea1: skipping, looped directory detected
# /usr/share/fonts/opentype/noto: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation2: skipping, looped directory detected
# /usr/share/fonts/truetype/libreoffice: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
# %%bash
# mkdir -p ~/.config/fontconfig
# cat > ~/.config/fontconfig/fonts.conf <<'EOF'
# <?xml version="1.0"?>
# <!DOCTYPE fontconfig SYSTEM "fonts.dtd">
# <fontconfig>
#
#   <!-- ▷ 한국어 텍스트엔 Noto Sans CJK KR을 우선 사용 -->
#   <match target="pattern">
#     <test name="lang" compare="eq"><string>ko</string></test>
#     <edit name="family" mode="prepend" binding="strong">
#       <string>Noto Sans CJK KR</string>
#     </edit>
#   </match>
#
#   <!-- ▷ 일반 가족명에도 기본 대체 추가 -->
#   <alias><family>sans-serif</family><prefer><family>Noto Sans CJK KR</family></prefer></alias>
#   <alias><family>serif</family><prefer><family>Noto Serif CJK KR</family></prefer></alias>
#   <alias><family>monospace</family><prefer><family>Noto Sans Mono CJK KR</family></prefer></alias>
#
#   <!-- ▷ Windows/macOS/웹에서 흔한 한글 폰트들을 Noto로 매핑 -->
#   <alias><family>Malgun Gothic</family>        <prefer><family>Noto Sans CJK KR</family></prefer></alias>
#   <alias><family>맑은 고딕</family>             <prefer><family>Noto Sans CJK KR</family></prefer></alias>
#   <alias><family>Apple SD Gothic Neo</family>  <prefer><family>Noto Sans CJK KR</family></prefer></alias>
#   <alias><family>AppleGothic</family>          <prefer><family>Noto Sans CJK KR</family></prefer></alias>
#   <alias><family>Pretendard</family>           <prefer><family>Noto Sans CJK KR</family></prefer></alias>
#   <alias><family>Pretendard Variable</family>  <prefer><family>Noto Sans CJK KR</family></prefer></alias>
#   <alias><family>NanumSquare</family>          <prefer><family>Noto Sans CJK KR</family></prefer></alias>
#   <alias><family>Spoqa Han Sans</family>       <prefer><family>Noto Sans CJK KR</family></prefer></alias>
#   <alias><family>KoPub</family>                <prefer><family>Noto Sans CJK KR</family></prefer></alias>
#   <alias><family>Gulim</family>                <prefer><family>Noto Sans CJK KR</family></prefer></alias>
#   <alias><family>Dotum</family>                <prefer><family>Noto Sans CJK KR</family></prefer></alias>
#   <alias><family>Batang</family>               <prefer><family>Noto Serif CJK KR</family></prefer></alias>
# </fontconfig>
# EOF
# fc-cache -fv
# Out:
# /usr/share/fonts: caching, new cache contents: 0 fonts, 4 dirs
# /usr/share/fonts/cMap: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap: caching, new cache contents: 0 fonts, 5 dirs
# /usr/share/fonts/cmap/adobe-cns1: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap/adobe-gb1: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap/adobe-japan1: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap/adobe-japan2: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap/adobe-korea1: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/opentype: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/opentype/noto: caching, new cache contents: 30 fonts, 0 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 5 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation2: caching, new cache contents: 12 fonts, 0 dirs
# /usr/share/fonts/truetype/libreoffice: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/cMap: skipping, looped directory detected
# /usr/share/fonts/cmap: skipping, looped directory detected
# /usr/share/fonts/opentype: skipping, looped directory detected
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-cns1: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-gb1: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-japan1: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-japan2: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-korea1: skipping, looped directory detected
# /usr/share/fonts/opentype/noto: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation2: skipping, looped directory detected
# /usr/share/fonts/truetype/libreoffice: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
# !apt-get -y install ffmpeg libreoffice poppler-utils
# !pip install reportlab
# !pip install tavily-python
# !pip install langchain_community
# !pip install langchain_openai
# !pip install langchain_core
# !pip install python-pptx pillow langgraph google-search-results gradio -q
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.12).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   at-spi2-core default-jre default-jre-headless firebird3.0-common
#   firebird3.0-common-doc firebird3.0-server-core firebird3.0-utils
#   fonts-crosextra-caladea fonts-crosextra-carlito fonts-dejavu
#   fonts-dejavu-core fonts-dejavu-extra fonts-linuxlibertine fonts-noto-core
#   fonts-noto-extra fonts-noto-mono fonts-noto-ui-core fonts-sil-gentium
#   fonts-sil-gentium-basic gsettings-desktop-schemas gstreamer1.0-gl
#   gstreamer1.0-gtk3 libabw-0.1-1 libatk-bridge2.0-0 libatk-wrapper-java
#   libatk-wrapper-java-jni libatk1.0-0 libatk1.0-data libatspi2.0-0 libbsh-java
#   libcolamd2 libe-book-0.1-1 libel-api-java libepubgen-0.1-1 libfbclient2
#   libgstreamer-gl1.0-0 libgtk-3-0 libgtk-3-bin libgtk-3-common libgudev-1.0-0
#   libhsqldb1.8.0-java libib-util libjsp-api-java liblibreoffice-java
#   libreoffice-base libreoffice-base-core libreoffice-base-drivers
#   libreoffice-calc libreoffice-gnome libreoffice-gtk3 libreoffice-java-common
#   libreoffice-math libreoffice-nlpsolver libreoffice-report-builder
#   libreoffice-report-builder-bin libreoffice-script-provider-bsh
#   libreoffice-script-provider-js libreoffice-script-provider-python
#   libreoffice-sdbc-firebird libreoffice-sdbc-hsqldb libreoffice-sdbc-mysql
#   libreoffice-sdbc-postgresql libreoffice-style-elementary
#   libreoffice-style-yaru libreoffice-wiki-publisher libreoffice-writer
#   librsvg2-common libservlet-api-java libservlet3.1-java libsuitesparseconfig5
#   libtommath1 libunoloader-java libwebsocket-api-java libwps-0.4-4
#   libxcomposite1 libxtst6 libxxf86dga1 lp-solve openjdk-11-jre
#   openjdk-11-jre-headless session-migration ure-java x11-utils
# Suggested packages:
#   firebird3.0-server firebird3.0-doc gvfs java-virtual-machine
#   libhsqldb1.8.0-java-gcj cups-bsd firefox | firefox-esr | thunderbird
#   ghostscript gpa hyphen-hyphenation-patterns imagemagick
#   | graphicsmagick-imagemagick-compat libreoffice-grammarcheck
#   libreoffice-help libreoffice-l10n libreoffice-librelogo myspell-dictionary
#   mythes-thesaurus openclipart-libreoffice pstoedit unixodbc
#   gstreamer1.0-plugins-good gstreamer1.0-plugins-ugly gstreamer1.0-plugins-bad
#   gstreamer1.0-libav libsane1 libofficebean-java libjtds-java libsqliteodbc
#   | tdsodbc | odbc-mdbtools libreoffice-evolution seahorse libreofficekit-data
#   default-mysql-server | virtual-mysql-server postgresql mediawiki libnss-mdns
#   fonts-ipafont-gothic fonts-ipafont-mincho fonts-wqy-microhei
#   | fonts-wqy-zenhei fonts-indic mesa-utils
# The following NEW packages will be installed:
#   at-spi2-core default-jre default-jre-headless firebird3.0-common
#   firebird3.0-common-doc firebird3.0-server-core firebird3.0-utils
#   fonts-crosextra-caladea fonts-crosextra-carlito fonts-dejavu
#   fonts-dejavu-core fonts-dejavu-extra fonts-linuxlibertine fonts-noto-core
#   fonts-noto-extra fonts-noto-mono fonts-noto-ui-core fonts-sil-gentium
#   fonts-sil-gentium-basic gsettings-desktop-schemas gstreamer1.0-gl
#   gstreamer1.0-gtk3 libabw-0.1-1 libatk-bridge2.0-0 libatk-wrapper-java
#   libatk-wrapper-java-jni libatk1.0-0 libatk1.0-data libatspi2.0-0 libbsh-java
#   libcolamd2 libe-book-0.1-1 libel-api-java libepubgen-0.1-1 libfbclient2
#   libgstreamer-gl1.0-0 libgtk-3-0 libgtk-3-bin libgtk-3-common libgudev-1.0-0
#   libhsqldb1.8.0-java libib-util libjsp-api-java liblibreoffice-java
#   libreoffice libreoffice-base libreoffice-base-core libreoffice-base-drivers
#   libreoffice-calc libreoffice-gnome libreoffice-gtk3 libreoffice-java-common
#   libreoffice-math libreoffice-nlpsolver libreoffice-report-builder
#   libreoffice-report-builder-bin libreoffice-script-provider-bsh
#   libreoffice-script-provider-js libreoffice-script-provider-python
#   libreoffice-sdbc-firebird libreoffice-sdbc-hsqldb libreoffice-sdbc-mysql
#   libreoffice-sdbc-postgresql libreoffice-style-elementary
#   libreoffice-style-yaru libreoffice-wiki-publisher libreoffice-writer
#   librsvg2-common libservlet-api-java libservlet3.1-java libsuitesparseconfig5
#   libtommath1 libunoloader-java libwebsocket-api-java libwps-0.4-4
#   libxcomposite1 libxtst6 libxxf86dga1 lp-solve openjdk-11-jre
#   openjdk-11-jre-headless session-migration ure-java x11-utils
# 0 upgraded, 84 newly installed, 0 to remove and 41 not upgraded.
# Need to get 188 MB of archives.
# After this operation, 758 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-base-core amd64 1:7.3.7-0ubuntu0.22.04.10 [974 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-base-drivers amd64 1:7.3.7-0ubuntu0.22.04.10 [602 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-base amd64 1:7.3.7-0ubuntu0.22.04.10 [1,725 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatspi2.0-0 amd64 2.44.0-3 [80.9 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 session-migration amd64 0.3.6 [9,774 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 gsettings-desktop-schemas all 42.0-1ubuntu1 [31.1 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 at-spi2-core amd64 2.44.0-3 [54.4 kB]
# Ign:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre-headless amd64 11.0.28+6-1ubuntu1~22.04.1
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# Ign:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.28+6-1ubuntu1~22.04.1
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre amd64 2:1.11-72build2 [896 B]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/universe amd64 firebird3.0-common-doc all 3.0.8.33535.ds4-1ubuntu2 [26.8 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/universe amd64 firebird3.0-common all 3.0.8.33535.ds4-1ubuntu2 [15.5 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtommath1 amd64 1.2.0-6ubuntu0.22.04.1 [56.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfbclient2 amd64 3.0.8.33535.ds4-1ubuntu2 [512 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libib-util amd64 3.0.8.33535.ds4-1ubuntu2 [3,378 B]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/universe amd64 firebird3.0-server-core amd64 3.0.8.33535.ds4-1ubuntu2 [2,533 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/universe amd64 firebird3.0-utils amd64 3.0.8.33535.ds4-1ubuntu2 [872 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-crosextra-caladea all 20130214-2.1 [82.4 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-crosextra-carlito all 20130920-1.1 [743 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-dejavu all 2.37-2build1 [3,192 B]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-linuxlibertine all 5.3.0-6 [1,627 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-core all 20201225-1build1 [12.2 MB]
# Err:9 http://security.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre-headless amd64 11.0.28+6-1ubuntu1~22.04.1
#   404  Not Found [IP: 91.189.91.83 80]
# Err:11 http://security.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.28+6-1ubuntu1~22.04.1
#   404  Not Found [IP: 91.189.91.83 80]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-noto-extra all 20201225-1build1 [72.4 MB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-mono all 20201225-1build1 [397 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-ui-core all 20201225-1build1 [1,420 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-sil-gentium all 20081126:1.03-4 [245 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-sil-gentium-basic all 1.102-1.1 [384 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-gl1.0-0 amd64 1.20.1-1ubuntu0.5 [204 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-gl amd64 1.20.1-1ubuntu0.5 [125 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-data all 2.36.0-3build1 [2,824 B]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-0 amd64 2.36.0-3build1 [51.9 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-bridge2.0-0 amd64 2.38.0-3 [66.6 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcomposite1 amd64 1:0.4.5-1build2 [7,192 B]
# Get:39 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-common all 3.24.33-1ubuntu2.2 [239 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-0 amd64 3.24.33-1ubuntu2.2 [3,053 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-gtk3 amd64 1.20.3-0ubuntu1.4 [33.3 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 libabw-0.1-1 amd64 0.1.3-1build3 [102 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbsh-java all 2.0b4-20 [289 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsuitesparseconfig5 amd64 1:5.10.1+dfsg-4build1 [10.4 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcolamd2 amd64 1:5.10.1+dfsg-4build1 [18.0 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/main amd64 libe-book-0.1-1 amd64 0.1.3-2build2 [148 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libel-api-java all 3.0.0-3 [64.9 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/main amd64 libepubgen-0.1-1 amd64 0.1.1-1ubuntu5 [120 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-bin amd64 3.24.33-1ubuntu2.2 [69.6 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libservlet-api-java all 4.0.1-2 [81.0 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjsp-api-java all 2.3.4-3 [53.7 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwebsocket-api-java all 1.1-2 [40.1 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libservlet3.1-java all 1:4.0.1-2 [9,276 B]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhsqldb1.8.0-java all 1.8.0.10+dfsg-11 [765 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libunoloader-java all 1:7.3.7-0ubuntu0.22.04.10 [13.0 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ure-java amd64 1:7.3.7-0ubuntu0.22.04.10 [83.5 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 liblibreoffice-java all 1:7.3.7-0ubuntu0.22.04.10 [1,604 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/main amd64 lp-solve amd64 5.5.2.5-2build2 [315 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwps-0.4-4 amd64 0.4.12-2build1 [812 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-calc amd64 1:7.3.7-0ubuntu0.22.04.10 [8,426 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-math amd64 1:7.3.7-0ubuntu0.22.04.10 [597 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-report-builder-bin amd64 1:7.3.7-0ubuntu0.22.04.10 [971 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-writer amd64 1:7.3.7-0ubuntu0.22.04.10 [10.3 MB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice amd64 1:7.3.7-0ubuntu0.22.04.10 [12.9 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-gnome amd64 1:7.3.7-0ubuntu0.22.04.10 [72.9 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-gtk3 amd64 1:7.3.7-0ubuntu0.22.04.10 [509 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-java-common all 1:7.3.7-0ubuntu0.22.04.10 [621 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-report-builder all 1:7.3.7-0ubuntu0.22.04.10 [2,112 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-script-provider-bsh all 1:7.3.7-0ubuntu0.22.04.10 [42.3 kB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-script-provider-js all 1:7.3.7-0ubuntu0.22.04.10 [645 kB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-script-provider-python all 1:7.3.7-0ubuntu0.22.04.10 [16.5 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-sdbc-firebird amd64 1:7.3.7-0ubuntu0.22.04.10 [176 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-sdbc-hsqldb amd64 1:7.3.7-0ubuntu0.22.04.10 [135 kB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-sdbc-mysql amd64 1:7.3.7-0ubuntu0.22.04.10 [123 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-sdbc-postgresql amd64 1:7.3.7-0ubuntu0.22.04.10 [279 kB]
# Get:80 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-style-elementary all 1:7.3.7-0ubuntu0.22.04.10 [8,020 kB]
# Get:81 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-style-yaru all 1:7.3.7-0ubuntu0.22.04.10 [3,761 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-wiki-publisher all 1.2.0+LibO7.3.7-0ubuntu0.22.04.10 [7,930 B]
# Get:83 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Get:84 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-nlpsolver all 0.9+LibO7.3.7-0ubuntu0.22.04.10 [7,986 B]
# Fetched 146 MB in 2s (67.9 MB/s)
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/main/o/openjdk-lts/openjdk-11-jre-headless_11.0.28%2b6-1ubuntu1%7e22.04.1_amd64.deb  404  Not Found [IP: 91.189.91.83 80]
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/main/o/openjdk-lts/openjdk-11-jre_11.0.28%2b6-1ubuntu1%7e22.04.1_amd64.deb  404  Not Found [IP: 91.189.91.83 80]
# E: Unable to fetch some archives, maybe run apt-get update or try with --fix-missing?
# Collecting reportlab
#   Downloading reportlab-4.4.5-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from reportlab) (11.3.0)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from reportlab) (3.4.4)
# Downloading reportlab-4.4.5-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 69.6 MB/s eta 0:00:00
# Installing collected packages: reportlab
# Successfully installed reportlab-4.4.5
# Collecting tavily-python
#   Downloading tavily_python-0.7.14-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from tavily-python) (2.32.4)
# Requirement already satisfied: tiktoken>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tavily-python) (0.12.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from tavily-python) (0.28.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.5.1->tavily-python) (2025.11.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->tavily-python) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->tavily-python) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->tavily-python) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->tavily-python) (2025.11.12)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx->tavily-python) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->tavily-python) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx->tavily-python) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx->tavily-python) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx->tavily-python) (4.15.0)
# Downloading tavily_python-0.7.14-py3-none-any.whl (17 kB)
# Installing collected packages: tavily-python
# Successfully installed tavily-python-0.7.14
# Collecting langchain_community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (1.1.0)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain_community)
#   Downloading langchain_classic-1.0.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.0.44)
# Collecting requests<3.0.0,>=2.32.5 (from langchain_community)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (9.1.2)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.4.47)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.22.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.0.0 (from langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Downloading langchain_text_splitters-1.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.12.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.15.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2025.11.12)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.2.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.41.4)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.3.1)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 62.8 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading langchain_classic-1.0.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 52.6 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 4.5 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.0.0-py3-none-any.whl (33 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.7 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: requests, mypy-extensions, marshmallow, typing-inspect, dataclasses-json, langchain-text-splitters, langchain-classic, langchain_community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# Successfully installed dataclasses-json-0.6.7 langchain-classic-1.0.0 langchain-text-splitters-1.0.0 langchain_community-0.4.1 marshmallow-3.26.1 mypy-extensions-1.1.0 requests-2.32.5 typing-inspect-0.9.0
# Collecting langchain_openai
#   Downloading langchain_openai-1.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain_openai) (1.1.0)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /usr/local/lib/python3.12/dist-packages (from langchain_openai) (2.8.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain_openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain_openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain_openai) (0.4.47)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain_openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain_openai) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain_openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain_openai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain_openai) (4.15.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (0.12.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2.32.5)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=1.109.1->langchain_openai) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain_openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain_openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain_openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain_openai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_openai) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_openai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_openai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.0->langchain_openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.0->langchain_openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.0->langchain_openai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain_openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain_openai) (2.5.0)
# Downloading langchain_openai-1.1.0-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.3/84.3 kB 6.4 MB/s eta 0:00:00
# Installing collected packages: langchain_openai
# Successfully installed langchain_openai-1.1.0
# Requirement already satisfied: langchain_core in /usr/local/lib/python3.12/dist-packages (1.1.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain_core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain_core) (0.4.47)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain_core) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain_core) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain_core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain_core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain_core) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain_core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.4.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (1.3.1)
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 24.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 10.8 MB/s eta 0:00:00
#   Building wheel for google-search-results (setup.py) ... done

# %%
# %%writefile main.py

import os

from langgraph.graph import StateGraph, END
from src.utils.state import State
import gradio as gr

from src.nodes.parse_slides import node_parse_all
from src.nodes.rag_search import node_tool_search
from src.nodes.gen_page_content import node_generate_page_content
from src.nodes.gen_script import node_generate_script
from src.nodes.tts import node_tts
from src.nodes.make_video import node_make_video
from src.nodes.accumulate_step import node_accumulate_and_step
from src.nodes.concat_video import node_concat
from src.nodes.make_quiz import node_generate_quiz
from src.nodes.router  import router_continue_or_done

# 출력 dir 만들기
WORK_DIR = "./gradio_output/"
MEDIA_DIR = os.path.join(WORK_DIR, "media")
SLIDES_DIR = os.path.join(WORK_DIR, "slides")

os.makedirs(WORK_DIR, exist_ok=True)
os.makedirs(MEDIA_DIR, exist_ok=True)
os.makedirs(SLIDES_DIR, exist_ok=True)

builder = StateGraph(State)

# ---- 노드 등록 ----
builder.add_node("parse_ppt", node_parse_all)
builder.add_node("tool_search", node_tool_search)
builder.add_node("gen_page_content", node_generate_page_content)
builder.add_node("gen_script", node_generate_script)
builder.add_node("tts", node_tts)
builder.add_node("make_video", node_make_video)
builder.add_node("accumulate", node_accumulate_and_step)
builder.add_node("concat", node_concat)
builder.add_node("make_quiz", node_generate_quiz)

# ---- 기본 흐름 연결 ----
builder.set_entry_point("parse_ppt")

builder.add_edge("parse_ppt", "tool_search")
builder.add_edge("tool_search", "gen_page_content")
builder.add_edge("gen_page_content", "gen_script")
builder.add_edge("gen_script", "tts")
builder.add_edge("tts", "make_video")
builder.add_edge("make_video", "accumulate")

# 조건 분기 라우터 등록
builder.add_conditional_edges(
    "accumulate",                    # 분기 기준 노드
    router_continue_or_done,         # 실행될 조건 함수
    {                                # 반환값에 따라 이동할 노드 지정
        "continue": "tool_search",   # 남은 슬라이드가 있을 때
        "done": "concat"             # 모든 슬라이드 완료 시
    }
)

builder.add_edge("concat", "make_quiz")
builder.add_edge("make_quiz", END)
# builder.add_edge("concat", "make_quiz")
# builder.add_edge("make_quiz", END)

# ---- 그래프 컴파일 ----
app = builder.compile()

def generate_state_and_run(pptx_file, tone, voice, style, target_duration_sec, speed):

    pptx_path = pptx_file
    USER_PROMPT = {
        "tone": tone,
        "voice": voice,
        "style": style,
        "target_duration_sec": int(target_duration_sec),
        "speed": float(speed)
    }

    state = {
        "pptx_path": pptx_path,
        "work_dir": WORK_DIR,
        # "work_dir": work_dir,
        "prompt": USER_PROMPT
    }

    # 실제 Agent 그래프(app) 실행
    state = app.invoke(state, config={"recursion_limit": 200})

    final_video = state.get("final_video", "")
    quiz_set = state.get("quiz_set", {})

    return final_video, final_video, quiz_set


# ===============================
# 🔹 복습 퀴즈 표시 함수
# ===============================
def display_quizzes(quiz_set):
    quizzes = get_quiz_list(quiz_set)

    if not quizzes:
        return "❌ 생성된 퀴즈가 없습니다."

    md = "## 🧠 복습 퀴즈\n\n"
    for i, q in enumerate(quizzes, 1):
        md += f"**Q{i}. {q['question']}**\n"
        for opt in q["options"]:
            md += f"- {opt}\n"
        md += "\n"
    return md


# ===============================
# 🔹 정답 표시 함수
# ===============================
def display_answers(quiz_set):
    """정답 보기 버튼 클릭 시 표시"""
    quizzes = get_quiz_list(quiz_set)

    if not quizzes:
        return "❌ 퀴즈 데이터가 없습니다."

    md = "## ✅ 정답 보기\n\n"
    for i, q in enumerate(quizzes, 1):
        md += f"**Q{i}.** {q['answer']}\n"
    return md


# ===============================
# 🔹 퀴즈 내용 전처리 함수
# ===============================
def get_quiz_list(quiz_set):
    if not quiz_set:
        return []
    if isinstance(quiz_set, dict) and "quiz" in quiz_set:
        qs = quiz_set["quiz"]
    else:
        qs = quiz_set
    if isinstance(qs, list):
        return [q for q in qs if isinstance(q, dict)]
    return []


# ===============================
# 🔹 개별 문제 불러오기 함수
# ===============================
def load_quiz_question(quiz_set, index):
    quizzes = get_quiz_list(quiz_set)

    if not quizzes:
        # 보기 리스트도 같이 초기화
        return (
            "❌ 퀴즈가 없습니다. 먼저 실행 버튼으로 퀴즈를 생성해 주세요.",
            gr.update(choices=["(문제를 먼저 불러오세요)"], value=None),
        )

    # index → 0-based 변환
    try:
        idx = int(index) - 1
    except:
        idx = 0

    if idx < 0:
        idx = 0
    if idx >= len(quizzes):
        idx = len(quizzes) - 1

    q = quizzes[idx]

    question_text = f"Q{idx + 1}. {q['question']}"
    options = q["options"]  # ['1. ...', '2. ...', '3. ...', '4. ...']

    return question_text, gr.update(choices=options, value=None)

def load_quiz_question_with_reset(quiz_set, index):
    question, options = load_quiz_question(quiz_set, index)
    return question, options, ""

# ===============================
# 🔹 정답 체크 함수
# ===============================
def check_quiz_answer(quiz_set, index, user_answer):
    quizzes = get_quiz_list(quiz_set)

    if not quizzes:
        return "❌ 퀴즈가 없습니다. 먼저 실행 버튼으로 퀴즈를 생성해 주세요."

    # index → 0-based
    try:
        idx = int(index) - 1
    except:
        idx = 0

    idx = max(0, min(idx, len(quizzes) - 1))

    q = quizzes[idx]
    correct = q["answer"]   # 예: "2"

    if not user_answer:
        return "❗ 먼저 보기를 하나 선택해 주세요."

    # 🔥 사용자가 선택한 보기에서 번호만 추출
    selected_number = user_answer.split(".")[0].strip()  # "2. 텍스트" → "2"

    # 🔥 번호만 비교
    if selected_number == correct:
        return (
            f"✅ 정답입니다!\n\n"
            f"정답: {correct}번\n\n"
            f"해설: {q.get('explanation', '해설이 제공되지 않았습니다.')}"
        )
    else:
        return (
            f"❌ 오답입니다.\n\n"
            f"선택한 답: {selected_number}번\n"
            f"정답: {correct}번"
        )


# ===============================
# 🔹 Gradio 인터페이스
# ===============================
tone_choices = [
    "친절하고 명료한 강의 톤",
    "열정적이고 에너지 넘치는 발표 톤",
    "차분하고 신뢰감 있는 설명 톤",
    "격식 있고 전문적인 톤"
]

voice_choices = [
    "기본 설명형 -nova",
    "교육·온라인 수업용 -alloy",
    "감정 전달 중심 -fable",
    "기술 세미나용 -onyx",
    "홍보·SNS용 -verse",
    "명상·상담용 -coral"
]

style_choices = [
    "예시와 핵심 요점 중심",
    "스토리텔링 중심",
    "데이터 기반 설명",
    "감정과 공감 중심"
]


with gr.Blocks(theme="soft", title="🎬 AI 슬라이드 강의 생성기") as demo:
    gr.Markdown("## 🎬 AI 슬라이드 강의 생성기")
    gr.Markdown("PPTX를 업로드하고, 말투·목소리·스타일·속도를 선택한 뒤 **실행**을 누르면 AI가 자동으로 강의 영상을 생성합니다.")

    # 입력 영역
    with gr.Row():
        inp_ppt = gr.File(label="🎞️ PPTX 파일 업로드", file_types=[".pptx"], type="filepath")

    with gr.Row():
        inp_tone  = gr.Radio(label="🗣️ 말투 (tone)", choices=tone_choices, value="친절하고 명료한 강의 톤")
        inp_voice = gr.Radio(label="🎤 목소리 (voice)", choices=voice_choices, value="기본 설명형 -nova")

    with gr.Row():
        inp_style = gr.Radio(label="🧩 스타일 (style)", choices=style_choices, value="예시와 핵심 요점 중심")
        inp_duration = gr.Number(label="📄 페이지 당 몇 초 분량", value=60, precision=0)
        inp_speed = gr.Slider(
            label="🎚️ 음성 속도 (Speed)",
            minimum=0.8,
            maximum=2.0,
            step=0.1,
            value=1.0,
            info="음성 재생 속도를 조절하세요 (0.8x~2.0x)"
        )

    run_btn = gr.Button("🚀 실행", variant="primary")

    # 출력 구역
    with gr.Row():
        out_video = gr.Video(label="📽️ 최종 동영상 미리보기", interactive=False)

    out_download = gr.DownloadButton(label="💾 동영상 다운로드")

    # 🔹 인터랙티브 퀴즈 영역 (문제 1개씩 풀기)
    gr.Markdown("### 🎯 인터랙티브 퀴즈 (문제별 선택)")

    with gr.Row():
        quiz_index = gr.Number(
            label="문제 번호",
            value=1,
            precision=0,
            interactive=True,
            minimum=1,
            maximum=10
        )
        load_quiz_btn = gr.Button("📥 이 번호의 문제 불러오기")

    current_question_md = gr.Markdown(label="현재 문제", value="(문제를 불러오세요)")
    current_options_radio = gr.Radio(
        label="보기 선택",
        choices=["(문제를 먼저 불러오세요)"],  # 기본 더미 choice
        value=None,                            # 초기값은 None
        interactive=True
    )

    check_btn = gr.Button("✅ 이 문제 정답 확인")
    check_result_md = gr.Markdown(label="결과", value="(정답 여부가 여기에 표시됩니다.)")

    # 내부 상태 저장용
    quiz_state = gr.State([])

    # 버튼 연결
    run_btn.click(
        fn=generate_state_and_run,
        inputs=[inp_ppt, inp_tone, inp_voice, inp_style, inp_duration, inp_speed],
        outputs=[out_video, out_download, quiz_state]
    )

    # 🔹 "문제 불러오기" 버튼 → 선택한 번호의 문제 + 보기 표시
    load_quiz_btn.click(
    fn=load_quiz_question_with_reset,
    inputs=[quiz_state, quiz_index],
    outputs=[current_question_md, current_options_radio, check_result_md]
    )

    # 🔹 "정답 확인" 버튼 → 사용자가 선택한 보기 기준으로 정답/오답 피드백
    check_btn.click(
        fn=check_quiz_answer,
        inputs=[quiz_state, quiz_index, current_options_radio],
        outputs=[check_result_md]
    )


demo.launch(share=True)
# Out:
# Overwriting main.py

# %%
# !python main.py
# Out:
# /content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/main.py:248: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(theme="soft", title="🎬 AI 슬라이드 강의 생성기") as demo:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://a2a974a71318dcc78e.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# 총 3장의 슬라이드를 처리합니다.
#
# === 1번째 슬라이드 처리 중 ===
# [DEBUG] soffice_bin: /usr/bin/soffice
# [DEBUG] lo_cmd: ['/usr/bin/soffice', '--headless', '-env:UserInstallation=file:///tmp/lo_profile', '--convert-to', 'pdf:impress_pdf_Export', '--outdir', '/content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/gradio_output/slides', '/tmp/gradio/45cee91fdffbd0e356305362defd8d7d00d8611755ef6bd9f3ef68e601cf6c14/sample2_test.pptx']
#   → 제목:모델 성능 모니터링, 본문:12, 표:0 이미지: 1 도형:0, 링크:0
#
# === 2번째 슬라이드 처리 중 ===
# [DEBUG] soffice_bin: /usr/bin/soffice
# [DEBUG] lo_cmd: ['/usr/bin/soffice', '--headless', '-env:UserInstallation=file:///tmp/lo_profile', '--convert-to', 'pdf:impress_pdf_Export', '--outdir', '/content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/gradio_output/slides', '/tmp/gradio/45cee91fdffbd0e356305362defd8d7d00d8611755ef6bd9f3ef68e601cf6c14/sample2_test.pptx']
#   → 제목:ML 모델에 영향을 줄 수 있는 요인, 본문:3, 표:0 이미지: 1 도형:0, 링크:0
#
# === 3번째 슬라이드 처리 중 ===
# [DEBUG] soffice_bin: /usr/bin/soffice
# [DEBUG] lo_cmd: ['/usr/bin/soffice', '--headless', '-env:UserInstallation=file:///tmp/lo_profile', '--convert-to', 'pdf:impress_pdf_Export', '--outdir', '/content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/gradio_output/slides', '/tmp/gradio/45cee91fdffbd0e356305362defd8d7d00d8611755ef6bd9f3ef68e601cf6c14/sample2_test.pptx']
#   → 제목:모델 모니터링 아키텍처, 본문:3, 표:1 이미지: 0 도형:0, 링크:0
# ---페이지 분해 state 결과---
# {'pptx_path': '/tmp/gradio/45cee91fdffbd0e356305362defd8d7d00d8611755ef6bd9f3ef68e601cf6c14/sample2_test.pptx', 'work_dir': './gradio_output/', 'prompt': {'tone': '열정적이고 에너지 넘치는 발표 톤', 'voice': '기본 설명형 -nova', 'style': '예시와 핵심 요점 중심', 'target_duration_sec': 60, 'speed': 1.0}, 'total_slides': 3, 'titles': ['모델 성능 모니터링', 'ML 모델에 영향을 줄 수 있는 요인', '모델 모니터링 아키텍처'], 'texts': ['모델 모니터링\n프로덕션 환경에서 ML 모델의 성능 및 동작을 지속적으로 추적, 분석, 평가하는 프로세스\n필요성 : 모델은 배포 후에도 품질 저하, 데이터 문제, 사용 환경 변화 등의 위험에 노출됨\n주요 리스크\n데이터/컨셉 드리프트\n데이터 품질 문제\n적대적 공격(예: prompt injection)\n연결된 앞 단계의 모델 오류 전파\n모니터링 목표\n문제 조기 탐지\n근본 원인 분석\n모델 동작 이해 및 투명한 문서화', '최초 정의한 문제의 컨셉 변화(Concept Drift)\n시간 경과에 따라 데이터 변수 또는 패턴 간의 관계가 지속적으로 변할 수 있음.\n모델 환경에 갑작스럽고 예상치 못한 변화가 발생하여 성능에 상당한 영향을 미칠 수 있는 상황(예 : COVID-19)', '두 가지 접근 방식\n배치(Batch) 모니터링 : 정해진 주기(일간, 주간 등)나 특정 이벤트 발생 시 모니터링\n실시간(Streaming) 모니터링 : ML 예측 서비스에서 발생한 데이터를 모니터링 시스템에 실시간으로 전송, 지속적으로 품질 지표를 계산 및 업데이트'], 'tables': [[], [], [[['항목', '배치 모니터링', '실시간 모니터링'], ['데이터 흐름', '정해진 시간마다', '스트리밍(실시간)'], ['적합한 환경', '일반 ML 서비스, 배치 처리', '실시간 예측 서비스'], ['속도', '느림 (지연 있음)', '빠름 (즉시 감지 가능)'], ['운영 비용', '낮음', '높음 (복잡한 인프라)'], ['한계', 'Abnormal 에 대한 지연된 탐지', 'Ground Truth 데이터 확인 지연 시 \n적용에 한계']]]], 'images': [['/content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/gradio_output/media/slide1_img_1.png'], ['/content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/gradio_output/media/slide2_img_1.png'], []], 'slide_image': ['/content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/gradio_output/slides/slide_1.png', '/content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/gradio_output/slides/slide_2.png', '/content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/gradio_output/slides/slide_3.png'], 'shape_texts': [[], [], []], 'links': [[], [], []], 'external_content': {'queries': [], 'summaries': [], 'references': []}}
# idx : 0
# title : 모델 성능 모니터링
# texts : 모델 모니터링
# 프로덕션 환경에서 ML 모델의 성능 및 동작을 지속적으로 추적, 분석, 평가하는 프로세스
# 필요성 : 모델은 배포 후에도 품질 저하, 데이터 문제, 사용 환경 변화 등의 위험에 노출됨
# 주요 리스크
# 데이터/컨셉 드리프트
# 데이터 품질 문제
# 적대적 공격(예: prompt injection)
# 연결된 앞 단계의 모델 오류 전파
# 모니터링 목표
# 문제 조기 탐지
# 근본 원인 분석
# 모델 동작 이해 및 투명한 문서화
# tables : []
# images : ['/content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/gradio_output/media/slide1_img_1.png']
# 질의 생성 : [{'text': '모델 성능 모니터링', 'context': 'title'}, {'text': '모델 성능 모니터링 모델 모니터링\n프로덕션 환경에서 ML 모델의 성능 및 동작을 지속적으로 추적, 분석, 평가하는 프로세스\n필요성 : 모델은 배포 후에도 품질 저하', 'context': 'title+text'}, {'text': '모델 성능 모니터링 slide1_img_1', 'context': 'title+image'}]
# 질문 내용 : 모델 성능 모니터링
# /content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/src/utils/tavily_search.py:28: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   res_tool = TavilySearchResults(
# [{'title': '모델 성능 모니터링(MLOps) 소개', 'url': 'https://docs.newrelic.com/kr/docs/mlops/get-started/intro-mlops/', 'snippet': '게다가 배포, 모니터링, 관리 및 거버넌스의 문제로 인해 운영에서 머신 러닝 모델의 75%가 전혀 사용되지 않고 있습니다. 모델 성능 모니터링은 운영 중인 모델의 행동과 효과를 모니터링하여 데이터 과학자와 MLOP 실무자에게 머신 러닝 애플리케이션에 대한 가시성을 제공합니다. 이를 통해 데이터 팀은 지속적인 개발, 테스트 및 운영 모니터링 프로세스를 생성하는 데브옵스 팀과 직접적으로 협업할 수 있습니다. 다음과 같은 몇 가지 옵션을 통해, 뉴렐릭 알림에서 모델 성능 모델링을 사용할 수 있습니다. BYOD(자체 데이터 사용)는 모든 환경(Python 스크립트, 컨테이너, Lambda 함수, SageMaker 등)에서 사용될 수 있으며, 모든 머신 러닝 프레임워크(Scikit-learn, Keras, Pytorch, Tensorflow, Jax 등)와 쉽게 통합될 수 있습니다. 단 몇 분 만에 모니터링하려는 다른 커스텀 메트릭과 함께 기능 분포, 통계 데이터 및 예측 분포를 확보할 수 있습니다. 이러한 옵션 중 하나를 사용해 몇 분 안에 머신 러닝 모델 성능 측정을 시작하려면 모델 성능 모니터링 퀵스타트를 확인해 보십시오. 완전하게 맞춤화 할 수 있는 대시보드를 통해 사용자는 총 요청, 평균 토큰/요청 및 모델 이름을 추적할 수 있습니다.', 'domain': 'docs.newrelic.com', 'score': 0.6529, 'score_detail': {'similarity': 0.5158, 'domain': 0.65, 'content': 1.0}}, {'title': 'ML 모델, 모니터링이 중요한 이유 | 인사이트리포트', 'url': 'https://www.samsungsds.com/kr/insights/ml_model_monitoring.html', 'snippet': '무브웍스(Moveworks)의 수석 제품 관리자 라훌 카얄라는 “ML 모델 모니터링은 기업이 ‘AI 예측의 이점’과 ‘예측 가능한 결과에 대한 니즈’ 간의 균형을 맞추는 데 도움을 줄 수 있다”라며, “자동화된 알림을 통해 ML 운영팀이 이상치를 실시간 감지하여 피해 발생 전에 대응할 시간을 확보할 수 있다”라고 설명했다. 하지만 대부분의 모델은 시장 변동성이 매우 높을 때 정확한 예측을 하는 데 어려움을 겪을 것이며, 모델 모니터링은 이를 경고할 수 있다. 또 ML 모니터링은 ML 모델 드리프트(예: 예측 대상의 기본 통계가 변경됐을 때의 개념 드리프트 또는 입력 데이터가 변경됐을 때의 데이터 드리프트 등)를 경고할 수 있다. ‘모델옵스, ML 모니터링, 모델 성능 관리’는 머신러닝 모델이 예상대로 작동하고, 신뢰할 수 있는 예측을 제공하도록 하는 관행 및 도구에 대한 용어다.', 'domain': 'www.samsungsds.com', 'score': 0.6519, 'score_detail': {'similarity': 0.5138, 'domain': 0.65, 'content': 1.0}}, {'title': '<지식 사전> MLOps란? AI의 성공을 좌우하는 머신러닝 운영 ...', 'url': 'https://blog.kakaocloud.com/131', 'snippet': '또한, 모든 과정을 버전 관리하고 문서화함으로써 특정 시점의 모델 성능을 정확히 재현할 수 있습니다. MLOps를 통해 운영 중인 모델의 성능을 지속적으로 모니터링할 수 있습니다. 또한, 입력 데이터의 분포 변화를 감지하여 모델 재학습이 필요한 시점을 파악할 수 있습니다. MLOps는 모델 개발부터 배포, 운영까지의 전 과정을 추적할 수 있게 합니다. 또한, 모델의 의사결정 과정을 설명할 수 있는 기능을 통합하여 AI의 책임성을 강화할 수 있습니다. 데이터 버전 관리를 통해 학습에 사용된 데이터셋의 버전을 추적하고, 모델 성능의 변화를 데이터 변화와 연관지어 분석할 수 있습니다. 이를 통해 모델 개발과 배포 주기를 크게 단축하고 운영의 안정성을 높일 수 있습니다. 이러한 종합적인 모니터링을 통해 모델의 성능 저하나 운영 이슈를 조기에 발견하고 대응할 수 있습니다. 이를 통해 모델 학습에 사용되는 데이터의 일관성을 유지하고 데이터 관련 이슈를 신속하게 파악하고 해결할 수 있습니다.', 'domain': 'blog.kakaocloud.com', 'score': 0.5718, 'score_detail': {'similarity': 0.3536, 'domain': 0.65, 'content': 1.0}}, {'title': 'Vertex AI Model Monitoring 소개', 'url': 'https://docs.cloud.google.com/vertex-ai/docs/model-monitoring/overview?hl=ko', 'snippet': 'Vertex AI Model Monitoring을 사용하면 필요에 따라 또는 정기적으로 모니터링 작업을 실행하여 테이블 형식 모델 품질을 추적할 수 있습니다. 예를 들어 Vertex AI Model Monitoring은 다음 그림과 같은 시각화를 제공할 수 있으며 이 시각화는 두 데이터 세트에서 그래프 2개를 오버레이합니다. Model Monitoring v2를 사용하면 모델 모니터를 구성하고 모니터링 작업을 실행한 후에 시간 경과에 따라 측정항목을 추적할 수 있습니다. Model Monitoring v2는 학습 데이터와 비교하여 프로덕션 데이터 분포 변경사항을 모니터링하거나 시간 경과에 따른 프로덕션 데이터 분포 변화를 추적할 수 있습니다. 마찬가지로 추론 데이터의 경우 Model Monitoring v2가 시간 경과에 따른 학습 데이터 또는 프로덕션 데이터 분포와 비교하여 예측 결과 분포 변경사항을 모니터링할 수 있습니다. 모델 성능을 유지할 수 있도록 Model Monitoring v1은 *편향* 및 *드리프트* 특성에 대한 모델 추론 입력 데이터를 모니터링합니다. Model Monitoring v1은 *범주형* 특성과 *숫자* 특성에 대한 특성 편향과 드리프트를 감지할 수 있습니다. * 숫자 특성의 경우 Vertex AI Model Monitoring은 가능한 특성 값 범위를 동일한 간격으로 나누고 각 간격에 속하는 특성 값의 수나 백분율을 계산합니다.', 'domain': 'docs.cloud.google.com', 'score': 0.5687, 'score_detail': {'similarity': 0.3475, 'domain': 0.65, 'content': 1.0}}, {'title': '2.15. 모델 성능 모니터링', 'url': 'https://docs.redhat.com/ko/documentation/red_hat_openshift_ai_cloud_service/1/html/serving_models/monitoring_model_performance', 'snippet': '단일 모델 제공 플랫폼에서 플랫폼에 배포된 특정 모델에 대한 성능 지표를 볼 수 있습니다. 단일 모델 제공 플랫폼에 배포된 특정 모델에 대해 다음 메트릭을 모니터링할 수 있습니다. 6. 아래로 스크롤하여 요청 수, 평균 응답 시간, CPU 사용률 및 메모리 사용률에 대한 데이터 그래프를 봅니다. UWM(User Workload Monitoring)에 대한 Grafana 메트릭 대시보드를 배포하여 단일 모델 제공 플랫폼에 배포된 모델의 성능 및 리소스 사용량 지표를 모니터링할 수 있습니다. * Grafana 인스턴스에서 KServe, vLLM 및 OVMS에 사용할 수 있는 사전 구성된 대시보드에 액세스할 수 있습니다. Grafana 인스턴스에 vLLM/GPU 지표 대시보드 배포 링크 복사링크가 클립보드에 복사되었습니다! 3. 다음 작업을 수행하여 YAML 파일의 `NAMESPACE` 및 `MODEL_NAME` 매개변수를 `input.env` 파일의 값으로 바꿉니다. Grafana 인스턴스에서 가속기 및 vLLM 메트릭 ...
# 질문 내용 : 모델 성능 모니터링 모델 모니터링
# 프로덕션 환경에서 ML 모델의 성능 및 동작을 지속적으로 추적, 분석, 평가하는 프로세스
# 필요성 : 모델은 배포 후에도 품질 저하
# [{'title': '소프트웨어 테스트란 무엇인가요?', 'url': 'https://www.ibm.com/kr-ko/think/topics/software-testing', 'snippet': '최신 소프트웨어 테스트 전략은 자동화, 인공 지능(AI)\xa0및 마이크로서비스와 같은 클라우드 네이티브 아키텍처의 발전과 함께 계속 진화하고 있습니다. 개발 시 충분한 테스트 공간을 확보하면 소프트웨어 안정성이 향상되고 오류가 더 적은 고품질 애플리케이션을 제공할 수 있습니다. * **탐색적 테스트:**탐색적 테스트는 소프트웨어 테스터가 소프트웨어 오류로 이어질 수 있는 예측하기 어려운 시나리오와 상황을 발견하는 데 도움이 됩니다. * **호환성 테스트:**호환성 테스트는 소프트웨어 애플리케이션이 다양한 장치, 운영 체제, 브라우저 및 네트워크 환경에서 예상대로 작동하는지 확인합니다. 효과적인 소프트웨어 테스트는 라이프사이클 전반에 걸쳐 소프트웨어를 검증하는 데 필요한 범위, 접근 방식 및 리소스를 간략하게 설명하는 견고한 테스트 계획에서 시작됩니다. 이를 통해 개발 프로세스 초기에 실제 테스트 환경에서 소프트웨어를 검증할 수 있으므로 설계를 개선하고 위험을 줄일 수 있습니다. 팀은 코드, 요구 사항, 디자인 문서, 모델, 테스트 스크립트 및 테스트 결과와 같은 자산에 액세스할 수 있습니다. 팀은 프로젝트의 전반적인 상태를 빠르게 확인하고 테스트, 개발 및 기타 프로젝트 요소 간의 관계를 모니터링할 수 있습니다. 생성형 AI 모델은 고급 머신 러닝 기술을 사용하여 소프트웨어 동작을 기반으로 동적 테스트 케이스를 생성할 수 있습니다.', 'domain': 'www.ibm.com', 'score': 0.4846, 'score_detail': {'similarity': 0.1792, 'domain': 0.65, 'content': 1.0}}, {'title': 'PlantPAx 분산제어시스템(DCS) 구성 및 구현 사용자 매뉴얼', 'url': 'https://literature.rockwellautomation.com/idc/groups/literature/documents/um/proces-um100_-ko-p.pdf', 'snippet': '통신 손실 서버/컨트롤러\uf613 통신\uf613평가 283 페이지\uf613참조 기술\uf613지원부에\uf613 문의 289 페이지\uf613참조 특정\uf613작업\uf613흐름이\uf613있는\uf613별도의\uf613절차 클라이언트/서버\uf613 통신\uf613평가 289 페이지\uf613참조 284 Rockwell Automation Publication PROCES-UM100B-KO-P - 2021 년5 월 \uf613부록D PlantPAx 문제\uf613해결\uf613시나리오 그림\uf61324 - 서버와\uf613컨트롤러\uf613간\uf613통신\uf613확인 라이브\uf613데이터\uf613현재\uf613품질\uf613양호 이\uf613절차는\uf613컨트롤러\uf613통신이\uf613서버\uf613수준에서\uf613사용\uf613가능한지\uf613여부를\uf613검사합니다. • FactoryTalk View SE 또는\uf613FactoryTalk View ME: - 파라미터\uf613파일\uf613표시 - 값, 표현식\uf613및\uf613애니메이션\uf613표시 - 전역\uf613객체\uf613파라미터 - 명령\uf613버튼\uf613및\uf613매크로 - 데이터\uf613로거 - 이벤트\uf613감지기 - 파생된\uf613태그 Rockwell Automation Publication PROCES-UM100B-KO-P - 2021 년5 월 289 \uf613부록D PlantPAx 문제\uf613해결\uf613시나리오 기술\uf613지원\uf613연락 다음\uf613사항을\uf613확인한\uf613후에도\uf613문제가\uf613계속되면\uf613로크웰\uf613오토메이션\uf613기술\uf613지원\uf613담당자에게 연락하십시오. 예 예 아니오 아니오 Ping 명령어\uf613평가\uf613- 290 페이지\uf613참조 이름\uf613분석\uf613평가\uf613- 290 페이지\uf613참조 애플리케이션\uf613 코드\uf613평가 288 페이지\uf613참조 290 Rockwell Automation Publication PROCES-UM100B-KO-P - 2021 년5 월 \uf613부록D PlantPAx 문제\uf613해결\uf613시나리오 핑\uf613명령어\uf613평가 클라이언트\uf613컴퓨터가\uf613서버와\uf613통신하는지\uf613확인하려면\uf613컴퓨터에\uf613ping을\uf613실행하여 시작합니다. 292 Rockwell Automation Publication PROCES-UM100B-KO-P - 2021 년5 월 \uf613부록D PlantPAx 문제\uf613해결\uf613시나리오 DNS Manager 디스플레이가\uf613나타납니다. Rockwell Automation Publication PROCES-UM100B-KO-P - 2021 년5 월 293 \uf613부록D PlantPAx 문제\uf613해결\uf613시나리오 애플리케이션\uf613코드\uf613형식\uf613검토 서버와\uf613컨트롤러가\uf613통신\uf613중이고\uf613문제가\uf613여전히\uf613존재하는\uf613경우\uf613프로젝트\uf613애플리케이션 코드를\uf613확인하는\uf613것이\uf613좋습니다.', 'domain': 'literature.rockwellautomation.com', 'score': 0.4521, 'score_detail': {'similarity': 0.1142, 'domain': 0.65, 'content': 1.0}}, {'title': 'iqwiki-kor/uf-g4o_translated-Qwen2.5-7B-distill-SFT-DPO- ...', 'url': 'https://huggingface.co/datasets/iqwiki-kor/uf-g4o_translated-Qwen2.5-7B-distill-SFT-DPO-beta0.1-seed8049/viewer/default/train', 'snippet': '이 방법을 통해 GPT를 활용하여 YouTube 비디오의 제목과 설명을 자동으로 생성할 수 있습니다. assistant GPT 모델을 사용하여 YouTube 비디오의 제목과 설명을 생성할 때, 다양한 종류의 데이터를 활용하면 더 정확하고 관련성이 높은 콘텐츠를 생성할 수 있습니다. 이러한 분석과 시각화를 통해 1929년 주식 시장 붕괴의 원인과 1930년대 대공황, 2008년 글로벌 금융 위기의 원인 및 결과를 명확히 이해할 수 있습니다. ```python import nltk from nltk.corpus import wordnet as wn # WordNet 초기화 nltk.download(\'wordnet\') ``` #### 단계 3: C++에서 Python 코드 호출 C++에서 파이썬 코드를 호출하기 위해 `pybind11` 라이브러리를 사용할 수 있습니다. 코드 예시 \\*\\*Python: 로봇이 요리를 시작하는 코드\\*\\* ```python import machine\\_vision import robotic\\_arm def start\\_cooking(recipe): ingredients = machine\\_vision.get\\_ingredients(recipe) robotic\\_arm.pick\\_and\\_place(ingredients) robotic\\_arm.cook(recipe) machine\\_vision.check\\_cooking(ingredients) # 예시: 파스타 요리 시작 start\\_cooking("pasta") ``` \\*\\*SQL: 데이터베이스에서 사용자 정보를 가져오는 코드\\*\\* ```sql SELECT \\* FROM user\\_data WHERE user\\_id = \'12345\'; ``` \\*\\*Python: 사 ...
# 질문 내용 : 모델 성능 모니터링 slide1_img_1
# []
# content='모델 성능 모니터링은 머신러닝 모델이 프로덕션 환경에서 지속적으로 최적의 성능을 발휘하도록 돕는 중요한 과정입니다. 모델은 배포 후에도 데이터 드리프트, 품질 문제, 환경 변화 등 다양한 위험에 노출될 수 있습니다. 이를 방지하기 위해 모니터링은 문제를 조기에 탐지하고 근본 원인을 분석하며, 모델의 동작을 투명하게 문서화하는 것을 목표로 합니다. 예를 들어, 최근 14일 동안 1820건의 예측 중 22건의 이상이 발견되었으며, 이는 예측과 실제 값 간의 차이로 나타났습니다. 이러한 모니터링은 데이터 과학자와 MLOps 팀이 협력하여 모델의 안정성을 유지하고 운영 효율성을 높이는 데 기여합니다[1][2][3].' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 190, 'prompt_tokens': 2171, 'total_tokens': 2361, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_83554c687e', 'id': 'chatcmpl-Ck3r6M4Y5pTtX0WIdfDUCNjQrlAWx', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--d1443c6b-efbe-47e8-ac0d-fdfca702705e-0' usage_metadata={'input_tokens': 2171, 'output_tokens': 190, 'total_tokens': 2361, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# --- Node 4: 강의 스크립트 생성(gen_script) 실행 ---
#    → 스크립트 생성 완료: ./gradio_output/script_0.txt
#
# --- Node 5: 교육용 TTS 변환 실행 ---
# [TTS] 교육용 보이스('nova')로 음성 생성 중...
# [FFmpeg] 1.0배속 변환 중...
# [TTS] 최종 오디오 길이: 59.81초
# [완료] 교육용 음성 파일 저장 → ./gradio_output/tts_slide0_1.0x.mp3
#
#
# --- Node 6: 슬라이드 영상 생성(make_video) 실행 ---
# [FFmpeg] 슬라이드 1 렌더링 중...
# [완료] 영상 생성 → ./gradio_output/slide1_lecture.mp4
# 슬라이드 1 완료 → ./gradio_output/slide1_lecture.mp4
#  진행률: 1/3 (33.3%)
#    성공: 1 | 실패: 0
#
# ➡️ 다음 슬라이드 처리 계속: 1/3
# ---페이지 분해 state 결과---
# {'pptx_path': '/tmp/gradio/45cee91fdffbd0e356305362defd8d7d00d8611755ef6bd9f3ef68e601cf6c14/sample2_test.pptx', 'work_dir': './gradio_output/', 'prompt': {'tone': '열정적이고 에너지 넘치는 발표 톤', 'voice': '기본 설명형 -nova', 'style': '예시와 핵심 요점 중심', 'target_duration_sec': 60, 'speed': 1.0}, 'slide_index': 1, 'total_slides': 3, 'titles': ['모델 성능 모니터링', 'ML 모델에 영향을 줄 수 있는 요인', '모델 모니터링 아키텍처'], 'texts': ['모델 모니터링\n프로덕션 환경에서 ML 모델의 성능 및 동작을 지속적으로 추적, 분석, 평가하는 프로세스\n필요성 : 모델은 배포 후에도 품질 저하, 데이터 문제, 사용 환경 변화 등의 위험에 노출됨\n주요 리스크\n데이터/컨셉 드리프트\n데이터 품질 문제\n적대적 공격(예: prompt injection)\n연결된 앞 단계의 모델 오류 전파\n모니터링 목표\n문제 조기 탐지\n근본 원인 분석\n모델 동작 이해 및 투명한 문서화', '최초 정의한 문제의 컨셉 변화(Concept Drift)\n시간 경과에 따라 데이터 변수 또는 패턴 간의 관계가 지속적으로 변할 수 있음.\n모델 환경에 갑작스럽고 예상치 못한 변화가 발생하여 성능에 상당한 영향을 미칠 수 있는 상황(예 : COVID-19)', '두 가지 접근 방식\n배치(Batch) 모니터링 : 정해진 주기(일간, 주간 등)나 특정 이벤트 발생 시 모니터링\n실시간(Streaming) 모니터링 : ML 예측 서비스에서 발생한 데이터를 모니터링 시스템에 실시간으로 전송, 지속적으로 품질 지표를 계산 및 업데이트'], 'tables': [[], [], [[['항목', '배치 모니터링', '실시간 모니터링'], ['데이터 흐름', '정해진 시간마다', '스트리밍(실시간)'], ['적합한 환경', '일반 ML 서비스, 배치 처리', '실시간 예측 서비스'], ['속도', '느림 (지연 있음)', '빠름 (즉시 감지 가능)'], ['운영 비용', '낮음', '높음 (복잡한 인프라)'], ['한계', 'Abnormal 에 대한 지연된 탐지', 'Ground Truth 데이터 확인 지연 시 \n적용에 한계']]]], 'images': [['/content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/gradio_output/media/slide1_img_1.png'], ['/content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/gradio_output/media/slide2_img_1.png'], []], 'slide_image': ['/content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/gradio_output/slides/slide_1.png', '/content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/gradio_output/slides/slide_2.png', '/content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/gradio_output/slides/slide_3.png'], 'external_content': {'queries': [], 'summaries': [], 'references': []}, 'shape_texts': [[], [], []], 'links': [[], [], []], 'page_content': '모델 성능 모니터링은 머신러닝 모델이 프로덕션 환경에서 지속적으로 최적의 성능을 발휘하도록 돕는 중요한 과정입니다. 모델은 배포 후에도 데이터 드리프트, 품질 문제, 환경 변화 등 다양한 위험에 노출될 수 있습니다. 이를 방지하기 위해 모니터링은 문제를 조기에 탐지하고 근본 원인을 분석하며, 모델의 동작을 투명하게 문서화하는 것을 목표로 합니다. 예를 들어, 최근 14일 동안 1820건의 예측 중 22건의 이상이 발견되었으며, 이는 예측과 실제 값 간의 차이로 나타났습니다. 이러한 모니터링은 데이터 과학자와 MLOps 팀이 협력하여 모델의 안정성을 유지하고 운영 효율성을 높이는 데 기여합니다[1][2][3].', 'script': '지금부터 모델 성능 모니터링에 대해 함께 살펴보겠습니다. 여러분, 머신러닝 모델이란 단순히 만들어서 배포하면 끝이 아니라는 것을 알고 계시죠? 바로 이 모델 성능 모니터링이 그 핵심입니다. 모델이 프로덕션 환경에 배포된 후에도 데이터 드리프트나 품질 문제, 그리고 환경 변화 같은 다양한 위험 요소에 노출될 수 있습니다. 그래서 우리는 이러한 문제를 조기에 탐지하고, 그 근본 원인을 분석하며, 모델의 동작을 투명하게 문서화하는 것이 중요합니다. 예를 들어, 최근 14일 동안 1820건의 예측 중 22건의 이상이 발견되었는데, 이는 예측과 실제 값 간의 차이로 나타났습니다. 이처럼 효과적인 모니터링은 데이터 과학자와 MLOps 팀이 협력하여 모델의 안정성을 유지하고 운영 효율성을 높이는 데 큰 도움을 줍니다. 결국, 우리의 목표는 모델이 항상 최적의 성능을 발휘할 수 있도록 돕는 것입니다.', 'all_scripts': ['지금부터 모델 성능 모니터링에 대해 함께 살펴보겠습니다. 여러분, 머신러닝 모델이란 단순히 만들어서 배포하면 끝이 아니라는 것을 알고 계시죠? 바로 이 모델 성능 모니터링이 그 핵심입니다. 모델이 프로덕션 환경에 배포된 후에도 데이터 드리프트나 품질 문제, 그리고 환경 변화 같은 다양한 위험 요소에 노출될 수 있습니다. 그래서 우리는 이러한 문제를 조기에 탐지하고, 그 근본 원인을 분석하며, 모델의 동작을 투명하게 문서화하는 것이 중요합니다. 예를 들어, 최근 14일 동안 1820건의 예측 중 22건의 이상이 발견되었는데, 이는 예측과 실제 값 간의 차이로 나타났습니다. 이처럼 효과적인 모니터링은 데이터 과학자와 MLOps 팀이 협력하여 모델의 안정성을 유지하고 운영 효율성을 높이는 데 큰 도움을 줍니다. 결국, 우리의 목표는 모델이 항상 최적의 성능을 발휘할 수 있도록 돕는 것입니다.'], 'audio': './gradio_output/tts_slide0_1.0x.mp3', 'video_path': './gradio_output/slide1_lecture.mp4', 'video_paths': ['./gradio_output/slide1_lecture.mp4']}
# idx : 1
# title : ML 모델에 영향을 줄 수 있는 요인
# texts : 최초 정의한 문제의 컨셉 변화(Concept Drift)
# 시간 경과에 따라 데이터 변수 또는 패턴 간의 관계가 지속적으로 변할 수 있음.
# 모델 환경에 갑작스럽고 예상치 못한 변화가 발생하여 성능에 상당한 영향을 미칠 수 있는 상황(예 : COVID-19)
# tables : []
# images : ['/content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/gradio_output/media/slide2_img_1.png']
# 질의 생성 : [{'text': 'ML 모델에 영향을 줄 수 있는 요인', 'context': 'title'}, {'text': 'ML 모델에 영향을 줄 수 있는 요인 최초 정의한 문제의 컨셉 변화(Concept Drift)\n시간 경과에 따라 데이터 변수 또는 패턴 간의 관계가 지속적으로 변할 수 있음.\n모델 ', 'context': 'title+text'}, {'text': 'ML 모델에 영향을 줄 수 있는 요인 slide2_img_1', 'context': 'title+image'}]
# 질문 내용 : ML 모델에 영향을 줄 수 있는 요인
# [{'title': "모델옵스'가 예방할 수 있는 ML 모델의 '패착' 5가지 | ITWorld 학습하기 전에 어떤 ML 모델을 사용해야 할지 어떻게 알 수 있나요? -... AI/ML 기반 모델 개발, 과제와 해결방안은? - SAS", 'url': 'https://www.itworld.co.kr/article/3584757/모델옵스가-예방할-수-있는-ml-모델의-패착-5가지.html', 'snippet': '그리고 배포한 머신러닝 모델이 계획대로 작동하는지 확인하고자 지속해서 모니터링하고 개선하는 방법도 제시한다. 하지만 머신러닝 모델을 배포하는 과정에서 여러 실패 요인이 간과된다. 다음은 모델옵스가 예방할 수 있는 데이터 모델의 실패 요인 5가지다. 6. 도메인 지식: 모델 선택에 영향을 줄 수 있는 도메인별 인사이트를 활용하세요. 특정 모델은 과거 실적이나 고유한 데이터 특성에 따라 특정 분야에 더 적합할 수 있습니다. 7. 모델 평가 지표: 모델 성능을 평가하는 데 사용할 지표를 정의합니다. AI/ ML 의 예측 모델은 과거 데이터에서 발생되는 패턴을 찾아 그 패턴 기반의 예측을 통해 의사결정과 실행을 합니다. 하지만 데이터의 학습 후에 발생된 데이터에서의 패턴이 항상 과거와 동일 할 수 없습니다. 예를 들어보겠습니다.', 'domain': 'www.itworld.co.kr', 'score': 0.6165, 'score_detail': {'similarity': 0.4431, 'domain': 0.65, 'content': 1.0}}, {'title': 'ML 모델, 모니터링이 중요한 이유 | 인사이트리포트 | 삼성SDS', 'url': 'https://www.samsungsds.com/kr/insights/ml_model_monitoring.html', 'snippet': '무브웍스(Moveworks)의 수석 제품 관리자 라훌 카얄라는 “ML 모델 모니터링은 기업이 ‘AI 예측의 이점’과 ‘예측 가능한 결과에 대한 니즈’ 간의 균형을 맞추는 데 도움을 줄 수 있다”라며, “자동화된 알림을 통해 ML 운영팀이 이상치를 실시간 감지하여 피해 발생 전에 대응할 시간을 확보할 수 있다”라고 설명했다. 하지만 대부분의 모델은 시장 변동성이 매우 높을 때 정확한 예측을 하는 데 어려움을 겪을 것이며, 모델 모니터링은 이를 경고할 수 있다. 또 ML 모니터링은 ML 모델 드리프트(예: 예측 대상의 기본 통계가 변경됐을 때의 개념 드리프트 또는 입력 데이터가 변경됐을 때의 데이터 드리프트 등)를 경고할 수 있다. ‘모델옵스, ML 모니터링, 모델 성능 관리’는 머신러닝 모델이 예상대로 작동하고, 신뢰할 수 있는 예측을 제공하도록 하는 관행 및 도구에 대한 용어다.', 'domain': 'www.samsungsds.com', 'score': 0.5513, 'score_detail': {'similarity': 0.3127, 'domain': 0.65, 'content': 1.0}}, {'title': '머신러닝에서 모델 성능이란 무엇인가요? | IBM', 'url': 'https://www.ibm.com/kr-ko/think/topics/model-performance', 'snippet': '인공 지능 (AI) 실무자는 ML 프로젝트의 초기 단계를 수행한 후 여러 데이터 세트, 작업, 지표에서 모델의 성능을 평가하여 모델의 효과를 측정합니다. AI 편향성은 워크플로의 어느 단계에서나 발생할 수 있지만, 특히 데이터 처리 및 모델 개발 단계에서 가장 많이 발생합니다. 과적합 및 과소적합을 방지하는 기술에는 모델이 학습할 수 있는 충분한 시간을 제공하기 위한 적절한 학습 기간 찾기, 학습 세트를 확장하기 위한 데이터 증강 , 더 큰 계수를 가진 입력 파라미터에 페널티를 적용하여 모델의 분산을 줄이기 위한 정규화 등이 있습니다. AI 모델   IBM Granite 살펴보기  IBM Granite는 비즈니스에 맞게 맞춤화되고 AI 애플리케이션 확장에 최적화되었으며 개방적이고 성능이 뛰어나며 신뢰할 수 있는 AI 모델 제품군입니다. AI 빌더를 위한 차세대 엔터프라이즈 스튜디오인 IBM watsonx.ai로 생성형 AI, 파운데이션 모델 및 머신 러닝 기능을 학습, 검증, 조정 및 배포하세요.', 'domain': 'www.ibm.com', 'score': 0.5159, 'score_detail': {'similarity': 0.2418, 'domain': 0.65, 'content': 1.0}}, {'title': '학습하기 전에 어떤 ML 모델을 사용해야 할지 어떻게 알 수 있나요? -...', 'url': 'https://ko.eitca.org/인공-지능/eitc-ai-gcml-Google-클라우드-머신-러닝/소개-a/머신-러닝이란?/학습하기-전에-어떤-ML-모델을-사용해야-할지-어떻게-알-수-있나요/', 'snippet': '6. 도메인 지식: 모델 선택에 영향을 줄 수 있는 도메인별 인사이트를 활용하세요. 특정 모델은 과거 실적이나 고유한 데이터 특성에 따라 특정 분야에 더 적합할 수 있습니다. 7. 모델 평가 지표: 모델 성능을 평가하는 데 사용할 지표를 정의합니다.', 'domain': 'ko.eitca.org', 'score': 0.4633, 'score_detail': {'similarity': 0.3976, 'domain': 0.65, 'content': 0.3475}}, {'title': '개발에서 프로덕션까지: 실제로 작동하는 ML 모델 배포', 'url': 'https://editverse.com/ko/from-development-to-production-deploying-ml-models-that-actually-work/', 'snippet': '모델 개선을 위한 피드백 루프 ML 모델 배포에는 효과적인 피드백 루프를 설정하는 것이 중요합니다. 모델이 제대로 작동하지 않을 수 있는 지점을 지속적으로 모니터링하세요. 24. 회사는 다음과 같은 고급 도구를 사용할 수 있습니다.', 'domain': 'editverse.com', 'score': 0.4184, 'score_detail': {'similarity': 0.3177, 'domain': 0.65, 'content': 0.3225}}, {'title': '프로덕션 ML 시스템: 질문 | Machine Learning | Google for Develope...', 'url': 'https://developers.google.com/machine-learning/crash-course/production-ml-systems/questions?hl=ko', 'snippet': '각 특성이 유용한지, 모델이 피드백 루프의 일부인지 등 프로덕션 ML 시스템을 감사하는 데 사용할 수 있는 질문을 알아봅니다.', 'domain': 'developers.google.com', 'score': 0.3996, 'score_detail': {'similarity': 0.3393, 'domain': 0.65, 'content': 0.175}}, {'title': 'AI/ML 기반 모델 개발, 과제와 해결방안은? - SAS', 'url': 'https://www.sas.com/content/dam/SAS/documents/marketing-whitepapers-ebooks/sas-whitepapers/ko/development-of-ai-ml-based-models-113648.pdf', 'snippet': 'AI/ ML 의 예측 모델은 과거 데이터에서 발생되는 패턴을 찾아 그 패턴 기반의 예측을 통해 의사결정과 실행을 합니다. 하지만 데이터의 학습 후에 발생된 데이터에서의 패턴이 항상 과거와 동일 할 수 없습니다. 예를 들어보겠습니다.', 'domain': 'www.sas.com', 'score': 0.3723, 'score_detail': {'similarity': 0.2256, 'domain': 0.65, 'content': 0.3225}}]
# 질문 내용 : ML 모델에 영향을 줄 수 있는 요인 최초 정의한 문제의 컨셉 변화(Concept Drift)
# 시간 경과에 따라 데이터 변수 또는 패턴 간의 관계가 지속적으로 변할 수 있음.
# 모델
# [{'title': '모델 드리프트', 'url': 'https://www.flowhunt.io/ko/%EC%9A%A9%EC%96%B4%EC%A7%91/model-drift/', 'snippet': '데모 로딩 중... AI 에이전트 플로우 컴포넌트 플로우 템플릿 지식 소스 지식 베이스 May 30, 2025에 게시됨. May 30, 2025에 3:30 am에서 마지막으로 수정됨 지금 시작하기 데모 예약 ### 모델 드리프트 탐지 방법 * **헬스케어**: 환자 결과 예측, 질병 위험 예측 모델은 새로운 의학 연구 결과나 환자 인구 변화에 맞춰 조정되어야 합니다. ## 모델 드리프트 관련 연구 모델 드리프트(Concept Drift)는 모델이 예측하려는 타겟 변수의 통계적 특성이 시간이 지남에 따라 변하는 현상입니다. :   모델 드리프트(또는 모델 붕괴)는 머신러닝 모델의 예측 성능이 환경, 입력 데이터, 또는 타겟 변수의 변화로 인해 시간이 지남에 따라 저하되는 현상입니다. 지금 시작하기 데모 예약 드롭아웃은 AI, 특히 신경망에서 과적합을 방지하기 위해 훈련 중 무작위로 뉴런을 비활성화하여 견고한 특성 학습과 새로운 데이터에 대한 일반화 능력을 향상시키는 정규화 기법입니다....', 'domain': 'www.flowhunt.io', 'score': 0.4832, 'score_detail': {'similarity': 0.1765, 'domain': 0.65, 'content': 1.0}}, {'title': 'Concept Drift에 의한 ML 모델 성능 변화의 정량적 추정 방법', 'url': 'https://kiss.kstudy.com/Detail/Ar?key=4027950', 'snippet': '한국정보처리학회;) 정보처리학회 논문지 (KTSDE);) Concept Drift에 의한 ML 모델 성능 변화의 정량적 추정 방법. Concept Drift에 의한 ML 모델 성능 변화의 정량적 추정 방법. Quantitative Estimation Method for ML Model Performance Change, Due to Concept Drift. 그러나 Concept drift는 모델 상태를 데이터 관계적으로 판단 할 뿐, 모델의 정량적 성능 수치를 추정하지는 못한다. 본 연구에서는 Concept drift의 통계량을 통해 정량적으로 precision 값을 추정하는 성능 예측 모델(PPM, Performance prediction model)을 제안한다. Academically, various studies have been conducted on the concept drift detection method to determine whether the model status is appropriate. The operational department wants to know quantitatively the performance of the operating model, but concept drift can only detect the state of the model in relation to the data, it cannot estimate the quantitative performance of the model. In this study, we propose a performance prediction model (PPM) that quantitatively estimates precision through the statistics of concept drift. Concept drift에의한 ML 모델 성능 변화의 정량적 추정 방법 4.', 'domain': 'kiss.kstudy.com', 'score': 0.4555, 'score_detail': {'similarity': 0.121, 'domain': 0.65, 'content': 1.0}}, {'title': 'Concept Drift에 의한 ML 모델 성능 변화의 정량적 추정 방법', 'url': 'https://www.kci.go.kr/kciportal/ci/sereArticleSearch/ciSereArtiView.kci?sereArticleSearchBean.artiId=ART002967973', 'snippet': '#### **Concept Drift에 의한 ML 모델 성능 변화의 정량적 추정 방법** Quantitative Estimation Method for ML Model Performance Change, Due to Concept Drift. #### **Concept Drift에 의한 ML 모델 성능 변화의 정량적 추정 방법** Quantitative Estimation Method for ML Model Performance Change, Due to Concept Drift 정보처리학회 논문지 The Transactions of the Korea Information Processing Society. Soon-Hong An, Hoon-Seok Lee and Seung-Hoon Kim. 2023, "Quantitative Estimation Method for ML Model Performance Change, Due to Concept Drift", The Transactions of the Korea Information Processing Society, vol.12, no.6 pp.259-266. Soon-Hong An, Hoon-Seok Lee, Seung-Hoon Kim "Quantitative Estimation Method for ML Model Performance Change, Due to Concept Drift" The Transactions of the Korea Information Processing Society 12.6 pp.259-266 (2023) : 259. "Quantitative Estimation Method for ML Model Performance Change, Due to Concept Drift" The Transactions of the Korea Information Processing Society 12, no.6 (2023) : 259-266. #### **Concept Drift에 의한 ML 모델 성능 변화의 정량적 추정 방법** Quantitative Estimation Method for ML Model Performance Change, Due to Concept Drift.', 'domain': 'www.kci.go.kr', 'score': 0.4404, 'score_detail': {'similarity': 0.0907, 'domain': 0.65, 'content': 1.0}}, {'title': 'Concept Drift에 의한 ML 모델 성능 변화의 정량적 추정 방법', 'url': 'https://koreascience.kr/article/JAKO202317936256458.page', 'snippet': 'Koh, "Detecting concept\xa0change in dynamic data streams," Machine Learning,\xa0Vol.97, No.3, pp.259-293, 2014. Yamauchi, "Detecting concept drift\xa0using statistical testing," in Proceedings of 10th International Conference on Discovery Science (DS\'07), in:\xa0Vol.4755 of (LNCS), Springer, pp.264-269, 2007. A. Maloof, "Dynamic weighted majority:\xa0an ensemble method for drifting concepts," The Journal\xa0of Machine Learning Research, Vol.8, pp.2755-2790, 2007. Barros, "Speeding up recovery from concept\xa0drifts," i ...
# 질문 내용 : ML 모델에 영향을 줄 수 있는 요인 slide2_img_1
# []
# content="머신러닝 모델의 성능은 시간이 지남에 따라 데이터 변수나 패턴의 변화, 즉 '컨셉 변화'에 의해 크게 영향을 받을 수 있습니다. 예를 들어, COVID-19와 같은 예기치 못한 사건은 모델의 예측 정확성에 큰 변화를 초래할 수 있습니다. 슬라이드의 그래프는 국가 봉쇄 조치 발표 후 실제 라운지웨어 판매량이 예측치와 크게 달라진 사례를 보여줍니다. 이러한 변화는 모델이 과거 데이터를 기반으로 학습했을 때 발생할 수 있는 문제점을 드러냅니다. 따라서 모델의 지속적인 모니터링과 개선이 중요하며, 이를 통해 모델 드리프트를 감지하고 대응할 수 있습니다 [1][2]." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 166, 'prompt_tokens': 2126, 'total_tokens': 2292, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_83554c687e', 'id': 'chatcmpl-Ck3tyKjjRIv2QJVc10fg1oznzkxC9', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--086189e1-fd4a-407f-9a36-51fb1f1a40d8-0' usage_metadata={'input_tokens': 2126, 'output_tokens': 166, 'total_tokens': 2292, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# --- Node 4: 강의 스크립트 생성(gen_script) 실행 ---
#    → 스크립트 생성 완료: ./gradio_output/script_1.txt
#
# --- Node 5: 교육용 TTS 변환 실행 ---
# [TTS] 교육용 보이스('nova')로 음성 생성 중...
# [FFmpeg] 1.0배속 변환 중...
# [TTS] 최종 오디오 길이: 51.6초
# [완료] 교육용 음성 파일 저장 → ./gradio_output/tts_slide1_1.0x.mp3
#
#
# --- Node 6: 슬라이드 영상 생성(make_video) 실행 ---
# [FFmpeg] 슬라이드 2 렌더링 중...
# [완료] 영상 생성 → ./gradio_output/slide2_lecture.mp4
# 슬라이드 2 완료 → ./gradio_output/slide2_lecture.mp4
#  진행률: 2/3 (66.7%)
#    성공: 2 | 실패: 0
#
# ➡️ 다음 슬라이드 처리 계속: 2/3
# ---페이지 분해 state 결과---
# {'pptx_path': '/tmp/gradio/45cee91fdffbd0e356305362defd8d7d00d8611755ef6bd9f3ef68e601cf6c14/sample2_test.pptx', 'work_dir': './gradio_output/', 'prompt': {'tone': '열정적이고 에너지 넘치는 발표 톤', 'voice': '기본 설명형 -nova', 'style': '예시와 핵심 요점 중심', 'target_duration_sec': 60, 'speed': 1.0}, 'slide_index': 2, 'total_slides': 3, 'titles': ['모델 성능 모니터링', 'ML 모델에 영향을 줄 수 있는 요인', '모델 모니터링 아키텍처'], 'texts': ['모델 모니터링\n프로덕션 환경에서 ML 모델의 성능 및 동작을 지속적으로 추적, 분석, 평가하는 프로세스\n필요성 : 모델은 배포 후에도 품질 저하, 데이터 문제, 사용 환경 변화 등의 위험에 노출됨\n주요 리스크\n데이터/컨셉 드리프트\n데이터 품질 문제\n적대적 공격(예: prompt injection)\n연결된 앞 단계의 모델 오류 전파\n모니터링 목표\n문제 조기 탐지\n근본 원인 분석\n모델 동작 이해 및 투명한 문서화', '최초 정의한 문제의 컨셉 변화(Concept Drift)\n시간 경과에 따라 데이터 변수 또는 패턴 간의 관계가 지속적으로 변할 수 있음.\n모델 환경에 갑작스럽고 예상치 못한 변화가 발생하여 성능에 상당한 영향을 미칠 수 있는 상황(예 : COVID-19)', '두 가지 접근 방식\n배치(Batch) 모니터링 : 정해진 주기(일간, 주간 등)나 특정 이벤트 발생 시 모니터링\n실시간(Streaming) 모니터링 : ML 예측 서비스에서 발생한 데이터를 모니터링 시스템에 실시간으로 전송, 지속적으로 품질 지표를 계산 및 업데이트'], 'tables': [[], [], [[['항목', '배치 모니터링', '실시간 모니터링'], ['데이터 흐름', '정해진 시간마다', '스트리밍(실시간)'], ['적합한 환경', '일반 ML 서비스, 배치 처리', '실시간 예측 서비스'], ['속도', '느림 (지연 있음)', '빠름 (즉시 감지 가능)'], ['운영 비용', '낮음', '높음 (복잡한 인프라)'], ['한계', 'Abnormal 에 대한 지연된 탐지', 'Ground Truth 데이터 확인 지연 시 \n적용에 한계']]]], 'images': [['/content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/gradio_output/media/slide1_img_1.png'], ['/content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/gradio_output/media/slide2_img_1.png'], []], 'slide_image': ['/content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/gradio_output/slides/slide_1.png', '/content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/gradio_output/slides/slide_2.png', '/content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/gradio_output/slides/slide_3.png'], 'external_content': {'queries': [], 'summaries': [], 'references': []}, 'shape_texts': [[], [], []], 'links': [[], [], []], 'page_content': "머신러닝 모델의 성능은 시간이 지남에 따라 데이터 변수나 패턴의 변화, 즉 '컨셉 변화'에 의해 크게 영향을 받을 수 있습니다. 예를 들어, COVID-19와 같은 예기치 못한 사건은 모델의 예측 정확성에 큰 변화를 초래할 수 있습니다. 슬라이드의 그래프는 국가 봉쇄 조치 발표 후 실제 라운지웨어 판매량이 예측치와 크게 달라진 사례를 보여줍니다. 이러한 변화는 모델이 과거 데이터를 기반으로 학습했을 때 발생할 수 있는 문제점을 드러냅니다. 따라서 모델의 지속적인 모니터링과 개선이 중요하며, 이를 통해 모델 드리프트를 감지하고 대응할 수 있습니다 [1][2].", 'script': "자, 모델을 배포한 이후에도 지속적으로 모니터링해야 한다는 점을 살펴봤습니다. 그렇다면, 모델 성능에 영향을 줄 수 있는 요인들에 대해 이야기해 보겠습니다. 시간이 지나면서 데이터의 변수나 패턴이 변화할 수 있는데, 이를 '컨셉 변화'라고 하죠. 예를 들어, 여러분 모두 기억하실 COVID-19 팬데믹과 같은 예기치 못한 사건은 모델의 예측 정확성에 큰 변화를 가져올 수 있습니다. 실제로 국가 봉쇄 조치가 발표된 이후 라운지웨어 판매량이 폭발적으로 증가한 사례가 있었습니다. 이런 현상들은 기존 데이터를 기반으로 학습한 모델에게는 큰 혼란을 줄 수 있습니다. 따라서 우리는 모델이 지속적으로 환경 변화에 적응할 수 있도록 모니터링과 개선에 힘써야 합니다. 이렇게 해야만 모델 드리프트를 조기에 감지하고, 필요할 때 적절히 대응할 수 있습니다.", 'all_scripts': ['지금부터 모델 성능 모니터링에 대해 함께 살펴보겠습니다. 여러분, 머신러닝 모델이란 단순히 만들어서 배포하면 끝이 아니라는 것을 알고 계시죠? 바로 이 모델 성능 모니터링이 그 핵심입니다. 모델이 프로덕션 환경에 배포된 후에도 데이터 드리프트나 품질 문제, 그리고 환경 변화 같은 다양한 위험 요소에 노출될 수 있습니다. 그래서 우리는 이러한 문제를 조기에 탐지하고, 그 근본 원인을 분석하며, 모델의 동작을 투명하게 문서화하는 것이 중요합니다. 예를 들어, 최근 14일 동안 1820건의 예측 중 22건의 이상이 발견되었는데, 이는 예측과 실제 값 간의 차이로 나타났습니다. 이처럼 효과적인 모니터링은 데이터 과학자와 MLOps 팀이 협력하여 모델의 안정성을 유지하고 운영 효율성을 높이는 데 큰 도움을 줍니다. 결국, 우리의 목표는 모델이 항상 최적의 성능을 발휘할 수 있도록 돕는 것입니다.', "자, 모델을 배포한 이후에도 지속적으로 모니터링해야 한다는 점을 살펴봤습니다. 그렇다면, 모델 성능에 영향을 줄 수 있는 요인들에 대해 이야기해 보겠습니다. 시간이 지나면서 데이터의 변수나 패턴이 변화할 수 있는데, 이를 '컨셉 변화'라고 하죠. 예를 들어, 여러분 모두 기억하실 COVID-19 팬데믹과 같은 예기치 못한 사건은 모델의 예측 정확성에 큰 변화를 가져올 수 있습니다. 실제로 국가 봉쇄 조치가 발표된 이후 라운지웨어 판매량이 폭발적으로 증가한 사례가 있었습니다. 이런 현상들은 기존 데이터를 기반으로 학습한 모델에게는 큰 혼란을 줄 수 있습니다. 따라서 우리는 모델이 지속적으로 환경 변화에 적응할 수 있도록 모니터링과 개선에 힘써야 합니다. 이렇게 해야만 모델 드리프트를 조기에 감지하고, 필요할 때 적절히 대응할 수 있습니다."], 'audio': './gradio_output/tts_slide1_1.0x.mp3', 'video_path': './gradio_output/slide2_lecture.mp4', 'video_paths': ['./gradio_output/slide1_lecture.mp4', './gradio_output/slide2_lecture.mp4']}
# idx : 2
# title : 모델 모니터링 아키텍처
# texts : 두 가지 접근 방식
# 배치(Batch) 모니터링 : 정해진 주기(일간, 주간 등)나 특정 이벤트 발생 시 모니터링
# 실시간(Streaming) 모니터링 : ML 예측 서비스에서 발생한 데이터를 모니터링 시스템에 실시간으로 전송, 지속적으로 품질 지표를 계산 및 업데이트
# tables : [[['항목', '배치 모니터링', '실시간 모니터링'], ['데이터 흐름', '정해진 시간마다', '스트리밍(실시간)'], ['적합한 환경', '일반 ML 서비스, 배치 처리', '실시간 예측 서비스'], ['속도', '느림 (지연 있음)', '빠름 (즉시 감지 가능)'], ['운영 비용', '낮음', '높음 (복잡한 인프라)'], ['한계', 'Abnormal 에 대한 지연된 탐지', 'Ground Truth 데이터 확인 지연 시 \n적용에 한계']]]
# images : []
# 질의 생성 : [{'text': '모델 모니터링 아키텍처', 'context': 'title'}, {'text': '모델 모니터링 아키텍처 두 가지 접근 방식\n배치(Batch) 모니터링 : 정해진 주기(일간, 주간 등)나 특정 이벤트 발생 시 모니터링\n실시간(Streaming) 모니', 'context': 'title+text'}, {'text': '모델 모니터링 아키텍처 항목 배치 모니터링 실시간 모니터링', 'context': 'title+table'}]
# 질문 내용 : 모델 모니터링 아키텍처
# [{'title': '가장 좋은 모델 모니터링 대시보드 아키텍처 다이어그램은 무엇 ...', 'url': 'https://www.qzymodels.com/ko/what-is-the-best-model-monitoring-dashboard-architecture-diagram/', 'snippet': '모델 모니터링 대시보드 아키텍처 다이어그램은 머신 러닝 모델이 프로덕션 환경에서 추적, 모니터링 및 관리되는 방식을 시각적으로 보여줍니다. 데이터 수집, 드리프트 감지, 성능 지표, 경고 시스템 및 시각화와 같은 구성 요소를 간략하게 설명하여 지속적인 모델 안정성과 성능을 보장합니다. 데이터 입력, 모니터링 기능, 알림 메커니즘 및 대시보드 인터페이스를 통해 실시간 또는 배치 모드에서 모델의 데이터 품질, 드리프트 및 성능 평가 방식을 체계적으로 보여줍니다. 조기 모니터링을 통해 데이터 드리프트, 모델 성능 저하 또는 편향을 적시에 감지하여 신속한 조치를 통해 영향을 최소화할 수 있습니다. 네, QZY Models는 고급 모델 모니터링 아키텍처를 통합하여 건축 및 산업 물리적 모델의 정확성과 신뢰성을 보장합니다. 중국 제조 부문은 디지털 혁신과 스마트 팩토리 이니셔티브를 강화하기 위해 모델 모니터링 대시보드를 빠르게 도입하고 있습니다. QZY Models의 접근 방식은 데이터 파이프라인, 실시간 분석 및 알림 메커니즘을 원활하게 통합하여 모델 충실도를 보장하는 고급 대시보드 아키텍처를 채택합니다. 당사는 파일 설계 최적화, 물리적 모델 인쇄, 샌딩 및 페인팅과 같은 후처리 서비스를 포함한 포괄적인 3D 인쇄 서비스를 제공합니다. 이는 복잡한 건축 모델, 조각품 및 산업 구성 요소를 생산하는 데 이상적입니다.', 'domain': 'www.qzymodels.com', 'score': 0.6539, 'score_detail': {'similarity': 0.5178, 'domain': 0.65, 'content': 1.0}}, {'title': "[번역] MLOps 아키텍처 가이드 - Taehun's Blog", 'url': 'https://blog.taehun.dev/mlops-architecture-guide', 'snippet': '아래는 프로젝트에 적합한 아키텍처를 찾을 때 볼 수 있는 복잡한 그림입니다 (복잡해 보이는 아키텍처이지만 지속적인 가치를 제공하는 프로덕션 등급 머신러닝 시스템을 구축하는 데 필요한 모든 것을 고려하지 않고 있습니다). MLOps의 일반적인 아키텍처 패턴에서 아키텍처 변경은 ML 단계와 Ops 단계에서 발생하며 문제와 데이터에 따라 다양한 개발 및 배포 패턴을 가질 수 있습니다. 또한 사용자가 학습 파이프라인 서비스로 요청을 전송하여 사용 가능한 데이터에 대한 학습을 시작하고 모델 데이터(학습 보고서)를 작성하는\xa0**사용자 트리거 (user-triggered) 학습 아키텍처**로 사용할 수도 있습니다. * 또한 학습 아키텍처에서는 모델 체크포인트를 활용하여 학습 및 재학습이 너무 오래 걸리지 않도록 할 수 있습니다(가급적이면 사용자가 로그인하는 시간이 가장 많은 시점부터 몇 시간 이내가 좋습니다). * **실험 관리**를 위해 Neptune을 사용하여 모델 학습이 재현 가능하고 하드웨어 사용량(CPU 및 메모리 사용량)과 하이퍼 파라미터 값에 대한 필요한 메타데이터가 기록되어 쉽게 시각화하고 공유할 수 있습니다. * 프로덕션 환경에 대한 운영 보안, 재해 복구, 전송 중 및 유휴 상태의 스트리밍 데이터 소스의 데이터 암호화와 같은 다른 방법을 계획할 수 있습니다.', 'domain': 'blog.taehun.dev', 'score': 0.5655, 'score_detail': {'similarity': 0.3411, 'domain': 0.65, 'content': 1.0}}, {'title': 'Tableau의 모델 모니터링 대시보드 아키텍처 다이어그램이란 무엇 ...', 'url': 'https://www.qzymodels.com/ko/what-is-a-model-monitoring-dashboard-architecture-diagram-in-tableau/', 'snippet': 'Tableau의 모델 모니터링 대시보드 아키텍처 다이어그램은 Tableau 구성 요소를 통해 데이터가 어떻게 흐르면서 분석 모델을 효과적으로 모니터링하는지 보여줍니다.', 'domain': 'www.qzymodels.com', 'score': 0.5492, 'score_detail': {'similarity': 0.6154, 'domain': 0.65, 'content': 0.2325}}, {'title': '모니터링 시스템을 디자인하고 만들기 위한 아키텍처 전략', 'url': 'https://learn.microsoft.com/ko-kr/azure/well-architected/operational-excellence/observability', 'snippet': '애플리케이션의 경우 수집 서비스는 계측 데이터를 생성하는 애플리케이션에서 자율적으로 실행할 수 있는 APM(애플리케이션 성능 관리) 도구일 수 있습니다. 많은 양의 이벤트 또는 많은 수의 데이터 요소를 모니터링하는 경우 Azure Event Hubs를 사용하여 처리 및 스토리지를 위해 데이터를 다른 컴퓨팅 인스턴스로 디스패치할 수 있습니다. 계측 데이터는 데이터를 결합하고 필터 및 정리 프로세스 역할을 하는 별도의 데이터 통합 서비스를 통과할 수 있습니다. 더 많은 분석 작업을 수행하거나 데이터에 대한 전체 텍스트 검색 기능이 필요한 경우 특정 유형의 쿼리 및 데이터 액세스에 최적화된 기능을 제공하는 데이터 스토리지를 사용하는 것이 더 적합할 수 있습니다. 대신 정보를 보관하는 데 사용되는 리포지토리에 따라 데이터를 직접 쿼리하거나 추가 분석 및 보고를 위해 Excel과 같은 도구로 가져올 수 있습니다. 관리자는 이 데이터를 사용하여 사용자가 지정된 기간 동안 청구할 수 있는 사용률 보고서를 생성할 수 있습니다.', 'domain': 'learn.microsoft.com', 'score': 0.4898, 'score_detail': {'similarity': 0.0096, 'domain': 0.95, 'content': 1.0}}, {'title': '이것이 모니터 아키텍처를 설계하는 방법입니다.', 'url': 'https://ko.itpedia.nl/2017/05/28/zo-geef-je-monitorarchitectuur-vorm/', 'snippet': '많은 조직이 합의된 서비스 표준을 측정 가능하게 하기 위해 모니터링 시설을 설정하는 데 어려움을 겪고 있습니다. 이 기사는 모니터링 시설 사용 중 문제를 방지하기 위해 모니터링 시설의 설계 및 레이아웃을 위한 서비스 관리 아키텍처에서 프레임워크를 설정하는 방법을 나타냅니다. 서비스 조직은 또한 비즈니스 거래 측정 및 추세 관찰과 같은 핵심 가치 흐름에 대한 모니터링 기능을 설정하고 구성할 수 있어야 합니다. 생산에 들어가면 서비스 조직과 비즈니스는 핵심 가치 흐름의 목표가 달성되지 않은 경우 서비스 조직 및/또는 사용자 조직을 개선하기 위해 측정 결과를 해석할 수 있어야 합니다. PR-Mon-02 원칙은 구성 요소가 중단된 경우 어떤 ICT 서비스가 영향을 받았는지 알 수 없는 것을 방지하는 데 사용할 수 있습니다. 사용자 조직과 서비스 조직 모두의 관리 요구는 ICT 서비스 모니터링 및 할당된 표준의 정의에 대한 기초를 형성합니다.', 'domain': 'ko.itpedia.nl', 'score': 0.4888, 'score_detail': {'similarity': 0.1876, 'domain': 0.65, 'content': 1.0}}, {'title': 'Vertex AI를 사용한 머신러닝 워크플로 - 모델 배포 및 모니터링 ...', 'url': 'https://partner.cloudskillsboost.google/course_templates/3/video/510785?locale=ko', 'snippet': '메시지 중심 아키텍처 · youtube_tv Apache Be ...
# 질문 내용 : 모델 모니터링 아키텍처 두 가지 접근 방식
# 배치(Batch) 모니터링 : 정해진 주기(일간, 주간 등)나 특정 이벤트 발생 시 모니터링
# 실시간(Streaming) 모니
# [{'title': '비용 최적화 요소 - AWS Well-Architected 프레임워크', 'url': 'https://docs.aws.amazon.com/ko_kr/wellarchitected/latest/cost-optimization-pillar/wellarchitected-cost-optimization-pillar.pdf', 'snippet': '즉, 워 COST10-BP02 정기적으로 워크로드 검토 및 분석 127 비용 최적화 요소 AWS Well-Architected 프레임워크 크로드에 사용하는 기존 서비스를 교체하거나 워크로드를 현대화하여 새로운 AWS 서비스를 채택해 야 할 수 있습니다. 리소스 관련 문서: • AWS 뉴스 블로그 • AWS의 새로운 소식 • AWS 설명서 • AWS Getting Started • AWS 일반 리소스 COST10-BP02 정기적으로 워크로드 검토 및 분석 128 비용 최적화 요소 AWS Well-Architected 프레임워크 관련 비디오: • AWS - This is My Architecture • AWS - Back to Basics • AWS - All-In series • How to Build This 운영 자동화 모범 사례 • COST11-BP01 운영 자동화 실행 COST11-BP01 운영 자동화 실행 자동화를 통해 관리 작업, 배포, 인적 오류 위험 완화, 규정 준수 및 기타 운영에 드는 시간과 노력을 정 량화하는 데 중점을 두고 클라우드에서의 운영 비용을 평가합니다.', 'domain': 'docs.aws.amazon.com', 'score': 0.4016, 'score_detail': {'similarity': 0.0131, 'domain': 0.65, 'content': 1.0}}, {'title': '2023 스마트미디어 심포지움', 'url': 'http://calsec.or.kr/databank/proceeding/23_symposium_paper.pdf', 'snippet': '웹브라우저를이용한OTT 콘텐츠시청 데이터분석방안 이찬우, 김성진, 허준영*, Sung Shin** *한성대학교 컴퓨터공학부, **South Dakota State University e-mail : temp2temp@hansung.ac.kr, trycatch98@gmail.com, jyheo@hansung.ac.kr, Sung.Shin@sdstate.edu How to analyze OTT content viewing data using a web browser Chanwoo Lee, Seongjin Kim, Junyoung Heo*, Sung Shin** *School of Computer Engineering, Hansung University, Korea **Electrical Engineering and Computer Science, South Dakota State University, USA 요 약 COVID-19로인해기존방송사의TV 시청방식에서유무선인터넷을이용한OTT 방식으로옮겨 감에따라많은OTT 전용콘텐츠가제작및유통되고있다. Available : https://developer.mozilla.or g/en-US/docs/Web/API/Media_Capture_and_Streams_AP I [5 October 2023].', 'domain': 'calsec.or.kr', 'score': 0.3979, 'score_detail': {'similarity': 0.0057, 'domain': 0.65, 'content': 1.0}}, {'title': 'vocab.txt', 'url': 'https://huggingface.co/deliciouscat/kf-deberta-base-cross-nli/resolve/main/vocab.txt?download=true', 'snippet': "... 을 하 의 가 은 고 , 한 지 를 기 으 1 있 대 도 으로 인 일 2 들 사 수 시 ( ) 로 했 아 전 해 에서 그 보 과 어 ' 자 것 적 주 만 정 부 나 라 상 면 중 제 등 게 경", 'domain': 'huggingface.co', 'score': 0.3354, 'score_detail': {'similarity': 0.1698, 'domain': 0.65, 'content': 0.2775}}, {'title': '국토공간정보의 빅데이터 관리, 분석 및 서비스 플랫폼 ...', 'url': 'https://www.codil.or.kr/filebank/original/RK/OTKCRK200030/OTKCRK200030.pdf', 'snippet': '- 공간 조인에 사용하는 내부 클러스터 캐쉬의 크기를 64mb와 128mb 두 가지. 경우로 하여 성능을 측정함. - (분석 기능 선정 기준) 성능 평가 환경은', 'domain': 'www.codil.or.kr', 'score': 0.3214, 'score_detail': {'similarity': 0.1638, 'domain': 0.65, 'content': 0.2225}}, {'title': '주력산업 고도화를 위한 지능형 상황인지 기반 기술 개발', 'url': 'https://ksp.etri.re.kr/ksp/report/file/18275.pdf', 'snippet': '- 모델의 구성 및 평가 방법. • GRU 순환신경망 기반의 7개 모델과 LSTM 순환신경망 기반의 7. 개 모델을 구성하여 상기 생성한 2 가지 타입의 데이터셋에 대. 해 실험.', 'domain': 'ksp.etri.re.kr', 'score': 0.3008, 'score_detail': {'similarity': 0.1116, 'domain': 0.65, 'content': 0.25}}, {'title': 'vol.50. no.2', 'url': 'https://www.theieie.org/download/academic_journal_special/202302.pdf', 'snippet': '본 특집호는 딥러닝 모델. 의 컴퓨팅에 있어서 최근 개발. 되고 있는 최적화 기술들을 살펴본다. 다양한 분야의 전문가. 들이 총 5편의 논문을 기고', 'domain': 'www.theieie.org', 'score': 0.2895, 'score_detail': {'similarity': 0.1071, 'domain': 0.65, 'content': 0.205}}, {'title': '블록체인 솔루션 & 기업 편람', 'url': 'https://blockchain.kisa.or.kr/file/2023_%EB%B8%94%EB%A1%9D%EC%B2%B4%EC%9D%B8_%EC%86%94%EB%A3%A8%EC%85%98_%EA%B8%B0%EC%97%85_%ED%8E%B8%EB%9E%8C.pdf', 'snippet': '모든 참여자가 데이터가 담긴 블록을 저장·공유하고 함께 인증하므로 소수에 의한 데이터 위·변조를 방지. 할 수 있는 기술. - 디지털 신뢰를 기반으로 계약 당사자', 'domain': 'blockchain.kisa.or.kr', 'score': 0.2889, 'score_detail': {'similarity': 0.0977, 'domain': 0.65, 'content': 0.225}}, {'title': '종합학술대회논문집', 'url': 'https://waf-e.dubudisk.com/kiice.dubuplus.com/anonymous/O18Br8A/DubuDisk/public/64B0065595E841ABBAFFF0B77B00299A.pdf', 'snippet': '주. 최 사단법인 한국정보통신학회. 후원기관 한국과학기술단체총연합회, 동의대학교. 후 원 사 SK브로드밴드, 대신정보통신(주), (주)대보정보통신,', 'domain': 'waf-e.dubudisk.com', 'score': 0.2888, 'score_detail': {'similarity': 0.1056, 'domain': 0.65, 'content': 0.205}}, {'title': '䁜ᡭ⯝  ㌜㍰䁙䆌 - file hanrimwon co., ltd.', ' ...
# 질문 내용 : 모델 모니터링 아키텍처 항목 배치 모니터링 실시간 모니터링
# [{'title': "제로부터 시작하는 MLOps 도구와 활용 - Taehun's Blog", 'url': 'https://blog.taehun.dev/from-zero-to-hero-mlops-tools-2', 'snippet': '모델 버전, 메타데이터 및 관련 아티팩트를 체계적으로 저장, 추적 및 관리할 수 있는 방법을 제공함으로써 MLOps 프로세스에서 중요한 역할을 합니다. 모델 레지스트리를 통해 머신러닝 팀은 모델 개발에서 효율적으로 협업하고, 모델 버전 관리를 유지하며, 프로덕션 환경에 모델을 쉽게 배포할 수 있습니다. 모델 서빙은 학습된 머신러닝 모델을 실제 프로덕션 환경에서 사용할 수 있게 하는 MLOps 시스템의 중요한 구성 요소입니다. 모델 서빙의 주요 측면에는 컨테이너화 또는 서버리스 플랫폼과 같은 배포 전략, 원활한 업데이트 및 롤백을 위한 버전 관리, 실시간 또는 수요가 많은 사용 사례를 처리할 수 있는 확장성 등이 포함됩니다. * MLOps 시스템은 *피처 스토어, 머신러닝 실험 환경, 소스 코드 리포지토리, CI/CD, 머신러닝 파이프라인, 메타데이터 저장소, 모델 레지스트리, 모델 서빙, 모니터링 및 트리거*와 같은 구성 요소로 이루어져 있습니다. * MLOps 시스템에서 머신러닝 모델 배포와 서빙은 *머신러닝 파이프라인, CI/CD, 모델 레지스트리, 모델 서빙, 모니터링* 구성 요소와 도구들로 수행 합니다.', 'domain': 'blog.taehun.dev', 'score': 0.5348, 'score_detail': {'similarity': 0.2796, 'domain': 0.65, 'content': 1.0}}, {'title': '애플리케이션 처리량과 반응성을 모니터링하는 방법', 'url': 'https://www.in-com.com/ko/blog/how-to-monitor-application-throughput-vs-responsiveness/', 'snippet': '세분화된 지연 시간 모니터 또는 애플리케이션 성능 모니터링 플랫폼과 같은 도구는 지연 발생 지점에 대한 자세한 가시성을 제공할 수 있습니다. 두 지표를 함께 모니터링하면 다양한 워크로드에서 성능 균형을 유지하는 더욱 정보에 기반한 용량 계획, 확장 의사 결정 및 최적화 전략을 수립할 수 있습니다. 성능 데이터를 운영 이벤트, 배포 변경 또는 워크로드 변화와 연계함으로써 팀은 이상 현상의 진정한 원인을 파악할 수 있습니다. 현재 부하에 따라 동시성 수준, 요청 우선순위 또는 배치 크기를 조정하는 적응형 정책을 사용하면 두 지표를 모두 목표 범위 내로 유지하는 데 도움이 될 수 있습니다. 강력한 거버넌스 프레임워크와 자동화된 통찰력을 통해 조직은 처리량과 대응성 간의 장기적인 성과 균형을 유지할 수 있으며, 최적화를 통해 운영 효율성과 최종 사용자 만족도를 모두 높일 수 있습니다. 와 SMART TS XL팀은 하나의 서비스 또는 프로세스의 변경이 전체 처리량과 개별 응답 시간에 미치는 영향을 추적할 수 있습니다. 삽입하여 SMART TS XL 성과 수명 주기를 통해 조직은 사후 대응적 문제 해결을 넘어 처리량과 대응성이 지속적으로 균형을 이루는 사전 최적화 전략으로 전환하여 운영 및 사용자 요구 사항을 충족할 수 있습니다.', 'domain': 'www.in-com.com', 'score': 0.489, 'score_detail': {'similarity': 0.188, 'domain': 0.65, 'content': 1.0}}, {'title': 'MLOps: 머신러닝의 지속적 배포 및 자동화 파이프라인', 'url': 'https://docs.cloud.google.com/architecture/mlops-continuous-delivery-and-automation-pipelines-in-machine-learning?hl=ko', 'snippet': 'MLOps을 수행하면 통합, 테스트, 출시, 배포, 인프라 관리를 비롯하여 ML 시스템 구성의 모든 단계에서 자동화 및 모니터링을 지원할 수 있습니다. 데이터 과학자는 사용 사례에 대한 특정한 관련 학습 데이터를 고려하여 오프라인 홀드아웃 데이터 세트에서 예측 성능을 갖춘 ML 모델을 구현하고 학습시킬 수 있습니다. 새 데이터를 사용하여 프로덕션 단계에서 모델을 재학습시키는 프로세스를 자동화하려면 파이프라인 트리거 및 메타데이터 관리뿐만 아니라 자동화된 데이터 및 모델 검증 단계를 파이프라인에 도입해야 합니다. * 구성요소 및 파이프라인의 모듈화된 코드: ML 파이프라인을 구성하려면 ML 파이프라인 전체에서 구성요소를 재사용, 구성, 공유할 수 있어야 합니다. * 데이터 검증: 이 단계는 모델 학습 전에 모델을 재학습할지 또는 파이프라인 실행을 중지할지 결정하는 데 필요합니다. 이 자동화된 CI/CD 시스템을 사용하면 데이터 과학자가 특성 추출, 모델 아키텍처, 초매개변수에 대한 새로운 아이디어를 빠르게 살펴볼 수 있습니다.', 'domain': 'docs.cloud.google.com', 'score': 0.4858, 'score_detail': {'similarity': 0.1816, 'domain': 0.65, 'content': 1.0}}, {'title': '프로덕션에 배포된 모델의 성능 모니터링', 'url': 'https://learn.microsoft.com/ko-kr/azure/machine-learning/how-to-monitor-model-performance?view=azureml-api-2', 'snippet': '# model-monitoring-with-collected-data.yaml $schema: http://azureml/sdk-2-0/Schedule.json name: fraud_detection_model_monitoring display_name: Fraud detection model monitoring description: Fraud detection model monitoring with your own production data trigger: # perform model monitoring activity daily at 3:15am type: recurrence frequency: day #can be minute, hour, day, week, month interval: 1 # #every day schedule: hours: 3 # at 3am minutes: 15 # at 15 mins after 3am create_monitor: compute: instance_type: standard_e4s_v3 runtime_version: "3.4" monitoring_target: ml_task: classification endpoint_deployment_id: azureml:fraud-detection-endpoint:fraud-detection-deployment monitoring_signals: advanced_data_drift: # monitoring signal name, any user defined name works type: data_drift # define production dataset with your collected data production_data: input_data: path: azureml:my_production_inference_data_model_inputs:1 # your collected data is registered as Azure Machine Learning asset type: uri_folder data_context: model_inputs pre_processing_component: azureml:production_data_preprocessing:1.0.0 reference_data: input_data: path: azureml:my_model_training_data:1 # use training data as comparison baseline type: mltable data_context: training data_c ...
# content='모델 모니터링 아키텍처는 머신 러닝 모델의 성능과 안정성을 유지하기 위해 필수적인 요소입니다. 배치 모니터링과 실시간 모니터링은 각각의 특성과 장점을 가지고 있습니다. 배치 모니터링은 정해진 주기마다 데이터를 수집하여 분석하며, 일반적인 ML 서비스에 적합하고 운영 비용이 낮습니다. 반면, 실시간 모니터링은 데이터를 즉시 전송하여 빠르게 품질 지표를 업데이트하며, 실시간 예측 서비스에 적합하지만 복잡한 인프라로 인해 운영 비용이 높습니다. 이러한 모니터링 시스템은 데이터 드리프트와 모델 성능 저하를 조기에 감지하여 신속한 대응을 가능하게 하며, 이는 모델의 지속적인 안정성과 성능을 보장하는 데 중요한 역할을 합니다 [1][2].' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 192, 'prompt_tokens': 1388, 'total_tokens': 1580, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_ed643dde95', 'id': 'chatcmpl-Ck3wBiTKqsg4BMAskUgJ7AYVQuPPo', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--4ae01b9a-83dc-44eb-b420-493658d1215a-0' usage_metadata={'input_tokens': 1388, 'output_tokens': 192, 'total_tokens': 1580, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# --- Node 4: 강의 스크립트 생성(gen_script) 실행 ---
#    → 스크립트 생성 완료: ./gradio_output/script_2.txt
#
# --- Node 5: 교육용 TTS 변환 실행 ---
# [TTS] 교육용 보이스('nova')로 음성 생성 중...
# [FFmpeg] 1.0배속 변환 중...
# [TTS] 최종 오디오 길이: 53.21초
# [완료] 교육용 음성 파일 저장 → ./gradio_output/tts_slide2_1.0x.mp3
#
#
# --- Node 6: 슬라이드 영상 생성(make_video) 실행 ---
# [FFmpeg] 슬라이드 3 렌더링 중...
# [완료] 영상 생성 → ./gradio_output/slide3_lecture.mp4
# 슬라이드 3 완료 → ./gradio_output/slide3_lecture.mp4
#  진행률: 3/3 (100.0%)
#    성공: 3 | 실패: 0
#
# 🎉 모든 슬라이드 처리 완료!
#    성공: 3
#    실패: 0
#
# 총 3개의 슬라이드 영상 병합 시작
# FFmpeg 병합 중 (filter_complex concat 사용)...
#  최종 강의 영상 생성 완료!
#  경로: ./gradio_output/final_lecture.mp4
#  총 재생 시간: 169.2초
#  파일 크기: 3.50 MB
#
# --- Node 10: 퀴즈 생성(make_quiz) 실행 ---
# [완료] 총 10개의 퀴즈 생성
# Keyboard interruption in main thread... closing server.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 3043, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/KT에이블스쿨/미니프로젝트3-(1~3)주차/생성형AI/ai_lecture-generator/main.py", line 330, in <module>
#     demo.launch(share=True)
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2950, in launch
#     self.block_thread()
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 3047, in block_thread
#     self.server.close()
#   File "/usr/local/lib/python3.12/dist-packages/gradio/http_server.py", line 69, in close
#     self.thread.join(timeout=5)
#   File "/usr/lib/python3.12/threading.py", line 1153, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/usr/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Killing tunnel 127.0.0.1:7860 <> https://a2a974a71318dcc78e.gradio.live
# ^C
